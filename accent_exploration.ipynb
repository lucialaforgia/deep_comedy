# %%
import pandas as pd
import os
from pprint import pprint

# %%
working_dir = os.path.join(os.path.abspath("."))
accents_vocab_file = os.path.join(working_dir, 'accent_vocab.csv')

# %%
accents_vocab = pd.read_csv(accents_vocab_file, sep='\t', header=0)

# %%
accents_vocab
# Out:
#               word searched_word   found_word        syllables     toned_word  \
# 0            abate         abate        abate          a-bà-te          abàte
# 1      abbandonato   abbandonato  abbandonato  ab-ban-do-nà-to    abbandonàto
# 2        abbandono     abbandono    abbandono     ab-ban-dó-no      abbandóno
# 3      abbarbaglio   abbarbaglio  abbarbaglio   ab-bar-bà-glio    abbarbàglio
# 4       abbondante    abbondante   abbondante    ab-bon-dàn-te     abbondànte
# ...            ...           ...          ...              ...            ...
# 12793       zenone  not_searched  not_founded         ze-no-ne  no_toned_word
# 12794           èe  not_searched  not_founded               èe  no_toned_word
# 12795          èli  not_searched  not_founded             è-li  no_toned_word
# 12796           èn  not_searched  not_founded               èn  no_toned_word
# 12797         èvvi  not_searched  not_founded            èv-vi  no_toned_word
#
#                        mode
# 0                        ok
# 1                        ok
# 2                        ok
# 3                        ok
# 4                        ok
# ...                     ...
# 12793  no_tone_pyphen_split
# 12794  no_tone_pyphen_split
# 12795  no_tone_pyphen_split
# 12796  no_tone_pyphen_split
# 12797  no_tone_pyphen_split
#
# [12798 rows x 6 columns]

# %% [markdown]
# #### Possible mode
# * **ok**: t word found in vocabulary, with tone and syllables
# * **toned_lemma_ok**: the lemma of the word found in vocabulary, with tone and syllables
# * **toned_found**: no lemma found, try to search the word and get what vocabulary return with tone and syllables
# * **no_tone_pyphen_split**: nothing found , syllables computed with pyphen module

# %%
modes = accents_vocab['mode'].unique().tolist()
pprint(modes)
# Out:
# ['ok', 'toned_lemma_ok', 'toned_found', 'no_tone_pyphen_split']

# %%
m = 'ok'

for m in modes:
    print('{:4d} words with mode \'{}\''.format(len(accents_vocab[accents_vocab['mode'] == m]), m))
# Out:
# 3818 words with mode 'ok'
# 4721 words with mode 'toned_lemma_ok'
#  572 words with mode 'toned_found'
# 3687 words with mode 'no_tone_pyphen_split'

# %%
accents_vocab[accents_vocab['mode'] == 'ok']
# Out:
#              word searched_word   found_word        syllables   toned_word  \
# 0           abate         abate        abate          a-bà-te        abàte
# 1     abbandonato   abbandonato  abbandonato  ab-ban-do-nà-to  abbandonàto
# 2       abbandono     abbandono    abbandono     ab-ban-dó-no    abbandóno
# 3     abbarbaglio   abbarbaglio  abbarbaglio   ab-bar-bà-glio  abbarbàglio
# 4      abbondante    abbondante   abbondante    ab-bon-dàn-te   abbondànte
# ...           ...           ...          ...              ...          ...
# 3813         zita          zita         zita            ẓì-ta         ẓìta
# 3814      zodiaco       zodiaco      zodiaco       ẓo-dì-a-co      ẓodìaco
# 3815         zona          zona         zona            ẓò-na         ẓòna
# 3816        zucca         zucca        zucca           zùc-ca        zùcca
# 3817        zuffa         zuffa        zuffa           zùf-fa        zùffa
#
#      mode
# 0      ok
# 1      ok
# 2      ok
# 3      ok
# 4      ok
# ...   ...
# 3813   ok
# 3814   ok
# 3815   ok
# 3816   ok
# 3817   ok
#
# [3818 rows x 6 columns]

# %%
accents_vocab[accents_vocab['mode'] == 'toned_lemma_ok']
# Out:
#             word searched_word  found_word      syllables  toned_word  \
# 3818     abbagli      abbaglio    abbaglio     ab-bà-glio    abbàglio
# 3819    abbaglia    abbagliare  abbagliare  ab-ba-glià-re  abbagliàre
# 3820  abbagliato    abbagliare  abbagliare  ab-ba-glià-re  abbagliàre
# 3821      abbaia      abbaiare    abbaiare    ab-ba-ià-re    abbaiàre
# 3822   abbaiando      abbaiare    abbaiare    ab-ba-ià-re    abbaiàre
# ...          ...           ...         ...            ...         ...
# 8534      vostre        vostro      vostro        vò-stro      vòstro
# 8535      vostri        vostro      vostro        vò-stro      vòstro
# 8536        voti          voto        voto          vó-to        vóto
# 8537       vuole        volere      volere       vo-lé-re      volére
# 8538           è        essere      essere       ès-se-re      èssere
#
#                 mode
# 3818  toned_lemma_ok
# 3819  toned_lemma_ok
# 3820  toned_lemma_ok
# 3821  toned_lemma_ok
# 3822  toned_lemma_ok
# ...              ...
# 8534  toned_lemma_ok
# 8535  toned_lemma_ok
# 8536  toned_lemma_ok
# 8537  toned_lemma_ok
# 8538  toned_lemma_ok
#
# [4721 rows x 6 columns]

# %%
accents_vocab[accents_vocab['mode'] == 'toned_found']
# Out:
#          word searched_word found_word     syllables toned_word         mode
# 8539  accaffi       accaffi  accaffare  ac-caf-fà-re  accaffàre  toned_found
# 8540  accarno       accarno  accarnare  ac-car-nà-re  accarnàre  toned_found
# 8541  acceffa       acceffa  acceffare  ac-cef-fà-re  acceffàre  toned_found
# 8542  accisma       accisma  accismare  ac-ci-ṣmà-re  acciṣmàre  toned_found
# 8543  accorse       accorse  accorrere  ac-cór-re-re  accórrere  toned_found
# ...       ...           ...        ...           ...        ...          ...
# 9106   zanche        zanche      zanca        zàn-ca      zànca  toned_found
# 9107   àncora        àncora     ancora      an-có-ra     ancóra  toned_found
# 9108       èi            èi         ei            éi         éi  toned_found
# 9109     ènne          ènne       enne         èn-ne       ènne  toned_found
# 9110      òra           òra        ora          ó-ra        óra  toned_found
#
# [572 rows x 6 columns]

# %%
accents_vocab[accents_vocab['mode'] == 'no_tone_pyphen_split']
# Out:
#           word searched_word   found_word  syllables     toned_word  \
# 9111         a  not_searched  not_founded          a  no_toned_word
# 9112        ab  not_searched  not_founded         ab  no_toned_word
# 9113   abbella  not_searched  not_founded  ab-bel-la  no_toned_word
# 9114      abbo  not_searched  not_founded      ab-bo  no_toned_word
# 9115   abborra  not_searched  not_founded  ab-bor-ra  no_toned_word
# ...        ...           ...          ...        ...            ...
# 12793   zenone  not_searched  not_founded   ze-no-ne  no_toned_word
# 12794       èe  not_searched  not_founded         èe  no_toned_word
# 12795      èli  not_searched  not_founded       è-li  no_toned_word
# 12796       èn  not_searched  not_founded         èn  no_toned_word
# 12797     èvvi  not_searched  not_founded      èv-vi  no_toned_word
#
#                        mode
# 9111   no_tone_pyphen_split
# 9112   no_tone_pyphen_split
# 9113   no_tone_pyphen_split
# 9114   no_tone_pyphen_split
# 9115   no_tone_pyphen_split
# ...                     ...
# 12793  no_tone_pyphen_split
# 12794  no_tone_pyphen_split
# 12795  no_tone_pyphen_split
# 12796  no_tone_pyphen_split
# 12797  no_tone_pyphen_split
#
# [3687 rows x 6 columns]

# %%
accents_vocab[accents_vocab['word'] == 'vai']
# Out:
#      word searched_word found_word syllables toned_word            mode
# 8327  vai          vaio       vaio     và-io       vàio  toned_lemma_ok

# %%
toned_df = accents_vocab[accents_vocab['mode'] == 'ok']
words_list = list(toned_df['toned_word'])

# %%
import string

vowels = "ÄäÁÀàáAaËëÉÈèéEeÏïÍÌíìIiÖöÓÒóòOoÜüÚÙúùUu"

to_keep = string.ascii_letters + vowels
to_keep

to_del = set()

for l in ''.join(list(toned_df['toned_word'])):
    if l not in to_keep:
        to_del.add(l)
to_del
# Out:
# {'ġ', 'ɑ', 'ɔ', 'ɛ', 'ʃ', 'ˈ', 'ː', 'ṣ', 'ẓ'}

# %%
new_word_list = []

for i, row in toned_df.iterrows():
    w = row['toned_word']
    normal_word = row['word']
    new_word = w
    if 'ɑ' in w:
        new_word = w.replace('ɑ', 'à')  
    if 'ġ' in w:
        new_word = w.replace('ġ', 'g')  
    if 'ɔ' in w:
        print(normal_word, w)
    if 'ɛ' in w:
        print(normal_word, w)
    if 'ʃ' in w:
        print(normal_word, w)
    if 'ˈ' in w:
        print(normal_word, w)
    if 'ː' in w:
        new_word = w.replace('ː', '')  
    if 'ṣ' in w:
        new_word = w.replace('ṣ', 's')  
    if 'ẓ' in w:
        new_word = w.replace('ẓ', 'z')  
           
    new_word_list.append(new_word)

toned_df['new_word'] = new_word_list
# Out:
# ahi ˈai
# cortes kˈɔrtes
# cortes kˈɔrtes
# deh dɛ
# fiche fiʃ
# poche pɔʃ
# poche pɔʃ
# uhi ˈui
# <ipython-input-104-1f75f83cae3b>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toned_df['new_word'] = new_word_list

# %%
for i, row in toned_df.iterrows():
    w = row['word']
    new_word = row['new_word']
    if 'k' in new_word:
        print(w, new_word)
# Out:
# cortes kˈɔrtes
# qu ku
# quai ke

# %%
toned_df[toned_df['word'] == 'quai']
# Out:
#       word searched_word found_word syllables toned_word mode new_word
# 2686  quai          quai       quai        ke         ke   ok       ke

# %%
toned_df.iloc[2686]['new_word'] = 'quài'

# %%
toned_df[toned_df['word'] == 'qu']
# Out:
#      word searched_word found_word syllables toned_word mode new_word
# 2682   qu            qu         qu        ku         ku   ok       ku

# %%
toned_df.iloc[2682]['new_word'] = 'qù'

# %%
toned_df[toned_df['new_word'] == 'kˈɔrtes']
# Out:
#        word searched_word found_word syllables toned_word mode new_word
# 802  cortes        cortes     cortes   kˈɔrtes    kˈɔrtes   ok  kˈɔrtes

# %%
toned_df.iloc[802]['new_word'] = 'cortès'

# %%
toned_df
# Out:
#              word searched_word   found_word        syllables   toned_word  \
# 0           abate         abate        abate          a-bà-te        abàte
# 1     abbandonato   abbandonato  abbandonato  ab-ban-do-nà-to  abbandonàto
# 2       abbandono     abbandono    abbandono     ab-ban-dó-no    abbandóno
# 3     abbarbaglio   abbarbaglio  abbarbaglio   ab-bar-bà-glio  abbarbàglio
# 4      abbondante    abbondante   abbondante    ab-bon-dàn-te   abbondànte
# ...           ...           ...          ...              ...          ...
# 3813         zita          zita         zita            ẓì-ta         ẓìta
# 3814      zodiaco       zodiaco      zodiaco       ẓo-dì-a-co      ẓodìaco
# 3815         zona          zona         zona            ẓò-na         ẓòna
# 3816        zucca         zucca        zucca           zùc-ca        zùcca
# 3817        zuffa         zuffa        zuffa           zùf-fa        zùffa
#
#      mode     new_word
# 0      ok        abàte
# 1      ok  abbandonàto
# 2      ok    abbandóno
# 3      ok  abbarbàglio
# 4      ok   abbondànte
# ...   ...          ...
# 3813   ok         zìta
# 3814   ok      zodìaco
# 3815   ok         zòna
# 3816   ok        zùcca
# 3817   ok        zùffa
#
# [3818 rows x 7 columns]

# %%
toned_vowels = "ÄäÁÀàáËëÉÈèéÏïÍÌíìÖöÓÒóòÜüÚÙúù"

toned_words = []
not_toned_words = []

for w, new_word in zip(list(toned_df['word']),list(toned_df['new_word'])):
    for c in new_word:
        if c in toned_vowels:
            toned_words.append(new_word)
            not_toned_words.append(w)
            break

# %%
print(len(not_toned_words))
print(len(toned_words))
# Out:
# 3808
# 3808

# %%
import csv

toned_dataset_file = os.path.join(working_dir, 'toned_dataset_file.csv')

f = open(toned_dataset_file, 'w')

writer = csv.writer(f, delimiter='\t')
row = ['word', 'index']

writer.writerow(row)


for w, toned_w in zip(not_toned_words, toned_words):
    toned_index = 0
    for c in toned_w:
        if c in toned_vowels:
            toned_index = toned_w.index(c) + 1
            break
    row = [w, toned_index]
    print(row)
    writer.writerow(row)

f.close()
# Out:
# ['abate', 3]
# ['abbandonato', 9]
# ['abbandono', 7]
# ['abbarbaglio', 7]
# ['abbondante', 7]
# ['abete', 3]
# ['abisso', 3]
# ['abito', 1]
# ['accedere', 4]
# ['acceso', 4]
# ['accetta', 4]
# ['accetto', 4]
# ['accidenti', 6]
# ['accidia', 4]
# ['accidioso', 7]
# ['acciò', 5]
# ['accline', 5]
# ['accoglienza', 8]
# ['accolta', 4]
# ['accolto', 4]
# ['accorgimento', 9]
# ['accorto', 4]
# ['accosto', 4]
# ['accusa', 4]
# ['acerbo', 3]
# ['aceto', 3]
# ['acqua', 1]
# ['acquisto', 5]
# ['acra', 1]
# ['acro', 1]
# ['acume', 3]
# ['acutamente', 7]
# ['acuto', 3]
# ['adamante', 5]
# ['addio', 4]
# ['addotto', 4]
# ['adesso', 3]
# ['adriano', 5]
# ['adulto', 3]
# ['adunque', 3]
# ['aere', 1]
# ['affanno', 4]
# ['affetto', 4]
# ['affettuoso', 8]
# ['affezione', 7]
# ['afflitto', 5]
# ['affocato', 6]
# ['affranto', 5]
# ['affricano', 7]
# ['agevole', 3]
# ['aggirata', 6]
# ['aggiunto', 5]
# ['agguato', 5]
# ['agnello', 4]
# ['agno', 1]
# ['ago', 1]
# ['agosto', 3]
# ['agra', 1]
# ['agricola', 4]
# ['agro', 1]
# ['agrume', 4]
# ['aguglia', 3]
# ['aguti', 3]
# ['aguto', 3]
# ['aguzzo', 3]
# ['ahimè', 5]
# ['ai', 1]
# ['aia', 1]
# ['aita', 2]
# ['aiuola', 4]
# ['aiuto', 3]
# ['aiutorio', 5]
# ['ala', 1]
# ['alabastro', 5]
# ['alba', 1]
# ['albergo', 4]
# ['albero', 1]
# ['alcuno', 4]
# ['ale', 1]
# ['alfa', 1]
# ['alimento', 5]
# ['alito', 1]
# ['allato', 4]
# ['alle', 1]
# ['allegrezza', 7]
# ['alleluia', 6]
# ['allevata', 6]
# ['allora', 4]
# ['alloro', 4]
# ['allotta', 4]
# ['alma', 1]
# ['alo', 1]
# ['alpe', 1]
# ['alpestre', 4]
# ['alpestro', 4]
# ['alquanto', 5]
# ['altamente', 6]
# ['alterazione', 9]
# ['altero', 4]
# ['altezza', 4]
# ['altissimo', 4]
# ['alto', 1]
# ['altresì', 7]
# ['altrettanto', 8]
# ['altri', 1]
# ['altrimenti', 7]
# ['altro', 1]
# ['altrove', 5]
# ['altrui', 5]
# ['altura', 4]
# ['alvo', 1]
# ['alzato', 4]
# ['amante', 3]
# ['amanza', 3]
# ['amare', 3]
# ['amaro', 3]
# ['amato', 3]
# ['ambage', 4]
# ['ambascia', 4]
# ['ambedue', 6]
# ['ambedui', 6]
# ['ambo', 1]
# ['ambra', 1]
# ['ambrosia', 5]
# ['amen', 1]
# ['amendue', 6]
# ['amico', 3]
# ['ammaestrato', 9]
# ['ammanto', 4]
# ['ammenda', 4]
# ['ammiraglio', 6]
# ['ammirando', 6]
# ['ammirazione', 9]
# ['amo', 1]
# ['amomo', 3]
# ['amore', 3]
# ['amoroso', 5]
# ['ampiezza', 5]
# ['ampio', 1]
# ['anca', 1]
# ['ancella', 4]
# ['anche', 1]
# ['anco', 1]
# ['ancoi', 4]
# ['ancora', 4]
# ['andare', 4]
# ['andata', 4]
# ['anello', 3]
# ['anelo', 3]
# ['angelica', 4]
# ['angelico', 4]
# ['angelo', 1]
# ['angoscia', 4]
# ['angoscioso', 8]
# ['angue', 1]
# ['anguilla', 5]
# ['anguinaia', 7]
# ['angusto', 4]
# ['animale', 5]
# ['anime', 1]
# ['animo', 1]
# ['anitra', 1]
# ['anno', 1]
# ['annunzio', 4]
# ['ante', 1]
# ['antico', 4]
# ['antivedere', 8]
# ['anzi', 1]
# ['ape', 1]
# ['aperto', 3]
# ['apparecchio', 6]
# ['apparenza', 6]
# ['appetito', 6]
# ['appoggio', 4]
# ['apprensiva', 8]
# ['appresso', 5]
# ['aprire', 4]
# ['aquario', 4]
# ['aquila', 1]
# ['aquilone', 6]
# ['ara', 1]
# ['arbitrio', 4]
# ['arbore', 1]
# ['arca', 1]
# ['arcano', 4]
# ['archimandrita', 11]
# ['arcivescovo', 6]
# ['arco', 1]
# ['ardente', 4]
# ['ardere', 1]
# ['ardimento', 6]
# ['ardire', 4]
# ['ardito', 4]
# ['ardore', 4]
# ['arene', 3]
# ['argento', 4]
# ['argine', 1]
# ['argo', 1]
# ['argomentare', 9]
# ['argomento', 6]
# ['arguto', 4]
# ['ariete', 4]
# ['aringo', 3]
# ['arma', 1]
# ['armato', 4]
# ['arme', 1]
# ['armento', 4]
# ['armonia', 6]
# ['arnese', 4]
# ['arpa', 1]
# ['arra', 1]
# ['arresto', 4]
# ['arriva', 4]
# ['arrivato', 6]
# ['arrivo', 4]
# ['arrogante', 6]
# ['arsi', 1]
# ['arsura', 4]
# ['arte', 1]
# ['artezza', 4]
# ['artificio', 6]
# ['artista', 4]
# ['arto', 1]
# ['arzanà', 6]
# ['asbergo', 4]
# ['ascesi', 4]
# ['asciutta', 5]
# ['asciutto', 5]
# ['ascolta', 4]
# ['ascoltare', 7]
# ['ascoso', 4]
# ['asperges', 4]
# ['aspettare', 7]
# ['aspetto', 4]
# ['aspro', 1]
# ['assai', 4]
# ['assale', 4]
# ['assalto', 4]
# ['assenso', 4]
# ['assenzo', 4]
# ['assiso', 4]
# ['assunto', 4]
# ['asta', 1]
# ['astio', 1]
# ['astro', 1]
# ['atleta', 4]
# ['attacco', 4]
# ['attendere', 4]
# ['attenti', 4]
# ['attento', 4]
# ['atteso', 4]
# ['attila', 1]
# ['attivo', 4]
# ['atto', 1]
# ['attuffare', 7]
# ['audienza', 5]
# ['augello', 4]
# ['augure', 1]
# ['augusto', 4]
# ['aula', 1]
# ['auna', 1]
# ['aura', 1]
# ['aurora', 4]
# ['austro', 1]
# ['autore', 4]
# ['autorità', 8]
# ['autunno', 4]
# ['avaccio', 3]
# ['avanti', 3]
# ['avarizia', 5]
# ['avaro', 3]
# ['ave', 1]
# ['avello', 3]
# ['avere', 3]
# ['avolo', 1]
# ['avvantaggio', 7]
# ['avversario', 7]
# ['avversaro', 7]
# ['avverso', 4]
# ['avviso', 4]
# ['avvocato', 6]
# ['azzurro', 4]
# ['babbo', 2]
# ['baco', 2]
# ['bada', 2]
# ['badia', 4]
# ['bagna', 2]
# ['bagnato', 5]
# ['baiulo', 2]
# ['balasso', 4]
# ['balco', 2]
# ['baldanza', 5]
# ['balena', 4]
# ['baleno', 4]
# ['balestra', 4]
# ['balestro', 4]
# ['balia', 4]
# ['ballo', 2]
# ['balzo', 2]
# ['banco', 2]
# ['banda', 2]
# ['bando', 2]
# ['bara', 2]
# ['baratta', 4]
# ['barattare', 7]
# ['baratteria', 9]
# ['barba', 2]
# ['barbare', 5]
# ['barbarossa', 7]
# ['barbuto', 5]
# ['barca', 2]
# ['barone', 4]
# ['basilica', 4]
# ['bassa', 2]
# ['basso', 2]
# ['basta', 2]
# ['basterna', 5]
# ['batista', 4]
# ['batisteo', 7]
# ['battaglia', 5]
# ['battesmo', 5]
# ['battezzato', 8]
# ['battuta', 5]
# ['bava', 2]
# ['be', 2]
# ['beato', 3]
# ['beatrice', 6]
# ['beccaio', 5]
# ['beccheria', 8]
# ['becchetto', 6]
# ['becco', 2]
# ['bee', 2]
# ['beffa', 2]
# ['bei', 2]
# ['bel', 2]
# ['bella', 2]
# ['belletta', 5]
# ['bellezza', 5]
# ['bello', 2]
# ['belo', 2]
# ['belva', 2]
# ['belzebù', 7]
# ['benda', 2]
# ['bene', 2]
# ['benedetto', 6]
# ['beneficio', 6]
# ['benignità', 9]
# ['benigno', 4]
# ['beninanza', 6]
# ['benvoglienza', 9]
# ['bere', 2]
# ['berta', 2]
# ['berzaglio', 5]
# ['bestemmia', 5]
# ['bestia', 2]
# ['bestialitade', 10]
# ['biacca', 3]
# ['bianca', 3]
# ['biancheggiare', 11]
# ['bianco', 3]
# ['biancovestito', 11]
# ['biasimo', 3]
# ['biasmo', 3]
# ['bieco', 3]
# ['bifolco', 4]
# ['biforme', 4]
# ['biga', 2]
# ['bigio', 2]
# ['bigoncia', 4]
# ['bilancia', 4]
# ['binato', 4]
# ['bionda', 3]
# ['biondo', 3]
# ['biscazza', 5]
# ['biscia', 2]
# ['bisogna', 4]
# ['bisogno', 4]
# ['bivero', 2]
# ['bizzarro', 5]
# ['bocca', 2]
# ['bogliente', 6]
# ['bolgia', 2]
# ['bologna', 4]
# ['bolognese', 7]
# ['bona', 2]
# ['bonaccia', 4]
# ['bontade', 5]
# ['bontate', 5]
# ['bontà', 5]
# ['bordello', 5]
# ['bordone', 5]
# ['borea', 2]
# ['borgo', 2]
# ['borsa', 2]
# ['bosco', 2]
# ['botto', 2]
# ['braccio', 3]
# ['braco', 3]
# ['brage', 3]
# ['bragia', 3]
# ['brago', 3]
# ['brama', 3]
# ['branca', 3]
# ['branda', 3]
# ['brano', 3]
# ['brenta', 3]
# ['breve', 3]
# ['brieve', 4]
# ['briga', 3]
# ['brigata', 5]
# ['brina', 3]
# ['broccia', 3]
# ['broda', 3]
# ['brollo', 3]
# ['brolo', 3]
# ['brullo', 3]
# ['bruno', 3]
# ['brusca', 3]
# ['bruto', 3]
# ['brutta', 3]
# ['brutto', 3]
# ['buca', 2]
# ['buccia', 2]
# ['buco', 2]
# ['bue', 2]
# ['bufera', 4]
# ['buffa', 2]
# ['bugiardo', 5]
# ['bugio', 2]
# ['buio', 2]
# ['bulicame', 6]
# ['bulla', 2]
# ['buono', 3]
# ['burella', 4]
# ['burrato', 5]
# ['burro', 2]
# ['busto', 2]
# ['butto', 2]
# ['caccia', 2]
# ['cacciata', 6]
# ['caco', 2]
# ['cacume', 4]
# ['cadere', 4]
# ['caduto', 4]
# ['cagione', 5]
# ['cagnazzo', 5]
# ['caino', 3]
# ['cala', 2]
# ['calando', 4]
# ['calare', 4]
# ['calca', 2]
# ['calda', 2]
# ['caldaia', 5]
# ['caldo', 2]
# ['cali', 2]
# ['caliga', 2]
# ['caligine', 4]
# ['calla', 2]
# ['callaia', 5]
# ['calle', 2]
# ['callo', 2]
# ['calo', 2]
# ['calvo', 2]
# ['camera', 2]
# ['camminata', 7]
# ['cammino', 5]
# ['camo', 2]
# ['campagna', 5]
# ['campare', 5]
# ['campo', 2]
# ['cancellare', 8]
# ['cancro', 2]
# ['candela', 5]
# ['candelo', 5]
# ['candente', 5]
# ['candido', 2]
# ['cane', 2]
# ['cangia', 2]
# ['caninamente', 8]
# ['canna', 2]
# ['canoscenza', 7]
# ['cantare', 5]
# ['cantaro', 5]
# ['cantato', 5]
# ['cantica', 2]
# ['cantilena', 7]
# ['canto', 2]
# ['canzone', 5]
# ['capere', 4]
# ['capestro', 4]
# ['capo', 2]
# ['capocchio', 4]
# ['cappa', 2]
# ['cappello', 5]
# ['cappia', 2]
# ['cappuccio', 5]
# ['capra', 2]
# ['capricorno', 7]
# ['caramente', 6]
# ['carbone', 5]
# ['carcere', 2]
# ['carco', 2]
# ['cardinale', 7]
# ['carezza', 4]
# ['caribo', 4]
# ['caritate', 6]
# ['carità', 6]
# ['carizia', 4]
# ['carne', 2]
# ['caro', 2]
# ['carpigna', 5]
# ['carpone', 5]
# ['carrarese', 7]
# ['carro', 2]
# ['carta', 2]
# ['casa', 2]
# ['cascata', 5]
# ['casella', 4]
# ['casentino', 7]
# ['caso', 2]
# ['cassino', 5]
# ['cassio', 2]
# ['casso', 2]
# ['castello', 5]
# ['casto', 2]
# ['catalano', 6]
# ['catalogna', 6]
# ['catena', 4]
# ['catenella', 6]
# ['cattivo', 5]
# ['catto', 2]
# ['causa', 2]
# ['cava', 2]
# ['cavallo', 4]
# ['caverna', 4]
# ['ce', 2]
# ['cedere', 2]
# ['ceffo', 2]
# ['cela', 2]
# ['celato', 4]
# ['celeste', 4]
# ['cena', 2]
# ['cenere', 2]
# ['cennamella', 7]
# ['cenno', 2]
# ['centauro', 5]
# ['centesimo', 5]
# ['centesma', 5]
# ['centesmo', 5]
# ['cento', 2]
# ['centro', 2]
# ['ceppo', 2]
# ['cera', 2]
# ['ceraste', 4]
# ['cerbero', 2]
# ['cerca', 2]
# ['cercare', 5]
# ['cerchia', 2]
# ['cerchiato', 7]
# ['cerchio', 2]
# ['cerco', 2]
# ['cerna', 2]
# ['cero', 2]
# ['cerro', 2]
# ['certamente', 7]
# ['certo', 2]
# ['cervello', 5]
# ['cervice', 5]
# ['cesare', 2]
# ['cespuglio', 5]
# ['cessa', 2]
# ['cesso', 2]
# ['cesto', 2]
# ['cetra', 2]
# ['che', 3]
# ['cherco', 3]
# ['chiama', 4]
# ['chiamare', 6]
# ['chiamata', 6]
# ['chiana', 4]
# ['chiappa', 4]
# ['chiara', 4]
# ['chiarezza', 6]
# ['chiarito', 6]
# ['chiarità', 8]
# ['chiaro', 4]
# ['chiavata', 6]
# ['chiave', 4]
# ['chiesa', 4]
# ['china', 3]
# ['chinare', 5]
# ['chinato', 5]
# ['chino', 3]
# ['chioccia', 4]
# ['chioma', 4]
# ['chiosa', 4]
# ['chiostra', 4]
# ['chiostro', 4]
# ['chiudere', 4]
# ['chiunque', 4]
# ['chiusa', 4]
# ['chiuso', 4]
# ['ciacco', 3]
# ['ciancia', 3]
# ['ciascheduno', 9]
# ['ciascuno', 6]
# ['cibo', 2]
# ['cicogna', 4]
# ['cieca', 3]
# ['cieco', 3]
# ['cielo', 3]
# ['ciglio', 2]
# ['cigno', 2]
# ['cilestro', 4]
# ['cima', 2]
# ['cimitero', 6]
# ['cincinnato', 8]
# ['cinghia', 2]
# ['cinghio', 2]
# ['cinquanta', 6]
# ['cinque', 2]
# ['cinquecento', 8]
# ['cinta', 2]
# ['cinto', 2]
# ['cintola', 2]
# ['cintura', 5]
# ['ciocca', 3]
# ['ciotto', 3]
# ['cioè', 4]
# ['circa', 2]
# ['circe', 2]
# ['circuito', 6]
# ['circunscritto', 10]
# ['cirro', 2]
# ['cisterna', 5]
# ['citarista', 6]
# ['cittadina', 7]
# ['cittadinanza', 9]
# ['cittadino', 7]
# ['città', 5]
# ['cive', 2]
# ['classe', 3]
# ['claustro', 3]
# ['clemente', 5]
# ['clemenza', 5]
# ['cleopatra', 6]
# ['clima', 3]
# ['clivo', 3]
# ['cloaca', 4]
# ['co', 2]
# ['cocca', 2]
# ['cocco', 2]
# ['coda', 2]
# ['cognazione', 8]
# ['coi', 2]
# ['col', 2]
# ['cola', 2]
# ['colei', 4]
# ['colle', 2]
# ['collega', 5]
# ['collegio', 5]
# ['collo', 2]
# ['colmo', 2]
# ['colombo', 4]
# ['colonna', 4]
# ['colorare', 6]
# ['colore', 4]
# ['coloro', 4]
# ['colpa', 2]
# ['colpo', 2]
# ['coltivare', 7]
# ['colto', 2]
# ['coltre', 2]
# ['coltura', 5]
# ['colui', 4]
# ['colà', 4]
# ['coma', 2]
# ['comanda', 4]
# ['comandamento', 9]
# ['comandare', 7]
# ['comandato', 7]
# ['comando', 4]
# ['combattuto', 8]
# ['combusto', 5]
# ['come', 2]
# ['comento', 4]
# ['comico', 2]
# ['cominciamento', 10]
# ['cominciare', 8]
# ['cominciato', 8]
# ['commessa', 5]
# ['commesso', 5]
# ['commosso', 5]
# ['como', 2]
# ['compage', 5]
# ['compagna', 5]
# ['compagnia', 8]
# ['compagno', 5]
# ['compatire', 7]
# ['compenso', 5]
# ['compianto', 6]
# ['compito', 5]
# ['compiuto', 6]
# ['compreso', 6]
# ['compressa', 6]
# ['compunto', 5]
# ['comune', 4]
# ['con', 2]
# ['conca', 2]
# ['concetto', 5]
# ['concilio', 5]
# ['concorde', 5]
# ['concordia', 5]
# ['concreato', 7]
# ['condanna', 5]
# ['condannato', 8]
# ['condizione', 8]
# ['condotta', 5]
# ['condotto', 5]
# ['condurre', 5]
# ['confesso', 5]
# ['confidare', 7]
# ['confine', 5]
# ['confitto', 5]
# ['confondere', 5]
# ['conformato', 8]
# ['conforme', 5]
# ['conforto', 5]
# ['confusione', 8]
# ['confuso', 5]
# ['congiunto', 6]
# ['congiurato', 8]
# ['conio', 2]
# ['conocchia', 4]
# ['conoscenza', 7]
# ['conosciuto', 8]
# ['consequenza', 8]
# ['conserva', 5]
# ['conservo', 5]
# ['consiglio', 5]
# ['consistoro', 8]
# ['consolare', 7]
# ['consorte', 5]
# ['consorzio', 5]
# ['constare', 6]
# ['consunto', 5]
# ['conta', 2]
# ['contastare', 8]
# ['contasto', 5]
# ['conte', 2]
# ['contegno', 5]
# ['contemplante', 9]
# ['contemplare', 9]
# ['contendere', 5]
# ['contenenza', 7]
# ['contento', 5]
# ['contesto', 5]
# ['contezza', 5]
# ['contingente', 8]
# ['contingenza', 8]
# ['continua', 5]
# ['continuamente', 10]
# ['continuo', 5]
# ['conto', 2]
# ['contra', 2]
# ['contrada', 6]
# ['contrario', 6]
# ['contro', 2]
# ['contumacia', 7]
# ['convegno', 5]
# ['convenenza', 7]
# ['convento', 5]
# ['conversione', 9]
# ['converso', 5]
# ['convolto', 5]
# ['coperchio', 4]
# ['coperto', 4]
# ['copia', 2]
# ['coppa', 2]
# ['coppo', 2]
# ['corata', 4]
# ['corda', 2]
# ['cordigliero', 9]
# ['core', 2]
# ['corno', 2]
# ['coro', 2]
# ['corollario', 7]
# ['corona', 4]
# ['coronato', 6]
# ['corpo', 2]
# ['corre', 2]
# ['corrente', 5]
# ['correre', 2]
# ['corretto', 5]
# ['corrotto', 5]
# ['corruttibile', 8]
# ['corruzione', 8]
# ['corsa', 2]
# ['corso', 2]
# ['corte', 2]
# ['cortes', 5]
# ['cortese', 5]
# ['cortesia', 7]
# ['corto', 2]
# ['cosa', 2]
# ['coscia', 2]
# ['coscienza', 6]
# ['cospetto', 5]
# ['costa', 2]
# ['costante', 5]
# ['costanza', 5]
# ['costei', 5]
# ['costellazione', 11]
# ['costinci', 5]
# ['costo', 2]
# ['costoro', 5]
# ['costrutto', 6]
# ['costui', 5]
# ['costuma', 5]
# ['costume', 5]
# ['costura', 5]
# ['costà', 5]
# ['costì', 5]
# ['così', 4]
# ['cotale', 4]
# ['cotanto', 4]
# ['cotenna', 4]
# ['cotesti', 4]
# ['cotesto', 4]
# ['coto', 2]
# ['cotta', 2]
# ['cotto', 2]
# ['cova', 2]
# ['coverta', 4]
# ['coverto', 4]
# ['cozzo', 2]
# ['crasso', 3]
# ['creato', 4]
# ['creatore', 6]
# ['creatura', 6]
# ['credenza', 5]
# ['credere', 3]
# ['credo', 3]
# ['crepa', 3]
# ['crepata', 5]
# ['crescendo', 6]
# ['cresciuta', 7]
# ['cresciuto', 7]
# ['cresta', 3]
# ['creta', 3]
# ['cria', 3]
# ['crine', 3]
# ['cristallo', 6]
# ['cristiano', 7]
# ['croce', 3]
# ['crollo', 3]
# ['crosta', 3]
# ['crucciare', 7]
# ['crucifisso', 7]
# ['crudele', 5]
# ['crudeltà', 8]
# ['crudo', 3]
# ['cruna', 3]
# ['cui', 2]
# ['culla', 2]
# ['cuna', 2]
# ['cunta', 2]
# ['cuoio', 3]
# ['cuore', 3]
# ['cupa', 2]
# ['cupidigia', 6]
# ['cupidità', 8]
# ['cupido', 2]
# ['cupo', 2]
# ['cura', 2]
# ['curio', 2]
# ['curro', 2]
# ['curule', 4]
# ['cuticagna', 6]
# ['dai', 2]
# ['dallato', 5]
# ['dannaggio', 5]
# ['danno', 2]
# ['dante', 2]
# ['danza', 2]
# ['dape', 2]
# ['dare', 2]
# ['data', 2]
# ['dato', 2]
# ['dattero', 2]
# ['davante', 4]
# ['davanti', 4]
# ['de', 2]
# ['dea', 2]
# ['debitamente', 8]
# ['debito', 2]
# ['decenne', 4]
# ['decimo', 2]
# ['decina', 4]
# ['deciso', 4]
# ['declivo', 5]
# ['decreto', 5]
# ['dedalo', 2]
# ['defunto', 4]
# ['degno', 2]
# ['dei', 2]
# ['deiforme', 5]
# ['deitade', 5]
# ['deità', 5]
# ['del', 2]
# ['deliro', 4]
# ['delizia', 4]
# ['delubro', 4]
# ['demonio', 4]
# ['denso', 2]
# ['dente', 2]
# ['dentro', 2]
# ['deriso', 4]
# ['deriva', 4]
# ['desiderato', 8]
# ['desiderio', 6]
# ['desideroso', 8]
# ['despetto', 5]
# ['desso', 2]
# ['destino', 5]
# ['desto', 2]
# ['destra', 2]
# ['destro', 2]
# ['determinato', 9]
# ['detta', 2]
# ['detto', 2]
# ['devoto', 4]
# ['diamante', 5]
# ['diana', 3]
# ['dianzi', 3]
# ['diavolo', 3]
# ['dica', 2]
# ['dicere', 2]
# ['dido', 2]
# ['die', 2]
# ['diece', 3]
# ['dieci', 3]
# ['dieta', 3]
# ['dietro', 3]
# ['difalta', 4]
# ['difesa', 4]
# ['difeso', 4]
# ['difetto', 4]
# ['differente', 7]
# ['differentemente', 12]
# ['diffuso', 5]
# ['digesto', 4]
# ['digiuno', 5]
# ['dignità', 7]
# ['dilettanza', 7]
# ['diletto', 4]
# ['dilettoso', 7]
# ['dimanda', 4]
# ['dimandare', 7]
# ['dimando', 4]
# ['dimane', 4]
# ['dimensione', 8]
# ['dimesso', 4]
# ['dimonio', 4]
# ['dimora', 4]
# ['dimoro', 4]
# ['dinanzi', 4]
# ['dindi', 2]
# ['dintorno', 5]
# ['dio', 2]
# ['dionisio', 5]
# ['dipartire', 7]
# ['dipartirsi', 7]
# ['dipartita', 7]
# ['dipinto', 4]
# ['dire', 2]
# ['diretto', 4]
# ['dirittamente', 9]
# ['diritto', 4]
# ['dirotto', 4]
# ['disagguaglianza', 12]
# ['disagio', 4]
# ['disanimato', 8]
# ['disbrigo', 6]
# ['discente', 5]
# ['discesa', 5]
# ['dischiuso', 7]
# ['disciolto', 6]
# ['disconvenevole', 10]
# ['discorde', 5]
# ['discordia', 5]
# ['discorso', 5]
# ['discreto', 6]
# ['disdegno', 5]
# ['disdegnoso', 8]
# ['disdetto', 5]
# ['disegno', 4]
# ['diserrare', 7]
# ['diserto', 4]
# ['disfatta', 5]
# ['disfatto', 5]
# ['disgiunto', 6]
# ['disianza', 5]
# ['disiato', 5]
# ['disio', 4]
# ['disioso', 5]
# ['disire', 4]
# ['dismisura', 7]
# ['disonesto', 6]
# ['disopra', 4]
# ['dispensa', 5]
# ['dispensare', 8]
# ['disperato', 7]
# ['dispetto', 5]
# ['dispettoso', 8]
# ['dispitto', 5]
# ['disporre', 5]
# ['disposto', 5]
# ['dispregiare', 9]
# ['dispregio', 6]
# ['distante', 5]
# ['distanza', 5]
# ['distesa', 5]
# ['disteso', 5]
# ['distinta', 5]
# ['distinto', 5]
# ['distinzione', 9]
# ['distretta', 6]
# ['distretto', 6]
# ['dito', 2]
# ['ditta', 2]
# ['diurno', 3]
# ['diva', 2]
# ['diversamente', 9]
# ['diverso', 4]
# ['dividendo', 6]
# ['divieto', 5]
# ['divino', 4]
# ['divisa', 4]
# ['diviso', 4]
# ['divizia', 4]
# ['divo', 2]
# ['divoto', 4]
# ['divozione', 7]
# ['doccia', 2]
# ['dodici', 2]
# ['doga', 2]
# ['doglia', 2]
# ['doglienza', 6]
# ['dolce', 2]
# ['dolcemente', 7]
# ['dolcezza', 5]
# ['dolente', 4]
# ['dolore', 4]
# ['doloroso', 6]
# ['dolzore', 5]
# ['doma', 2]
# ['domanda', 4]
# ['domine', 2]
# ['don', 2]
# ['donna', 2]
# ['donnescamente', 10]
# ['donno', 2]
# ['dono', 2]
# ['dopo', 2]
# ['doppia', 2]
# ['doppiero', 6]
# ['doppio', 2]
# ['dormi', 2]
# ['dosso', 2]
# ['dota', 2]
# ['dotato', 4]
# ['dote', 2]
# ['dotta', 2]
# ['dottore', 5]
# ['dottrina', 6]
# ['dove', 2]
# ['dovere', 4]
# ['drago', 3]
# ['dramma', 3]
# ['drappo', 3]
# ['dritta', 3]
# ['dritto', 3]
# ['drittura', 6]
# ['drizza', 3]
# ['drizzare', 6]
# ['drudo', 3]
# ['dubbiare', 6]
# ['dubbio', 2]
# ['duca', 2]
# ['duce', 2]
# ['due', 2]
# ['dunque', 2]
# ['duo', 2]
# ['duolo', 3]
# ['dura', 2]
# ['durabile', 4]
# ['duramente', 6]
# ['durata', 4]
# ['durezza', 4]
# ['duro', 2]
# ['ebbrezza', 5]
# ['ebro', 1]
# ['eccellente', 7]
# ['eccellenza', 7]
# ['eccelso', 4]
# ['eccesso', 4]
# ['ecco', 1]
# ['eclissi', 4]
# ['ed', 1]
# ['effetto', 4]
# ['effige', 4]
# ['ego', 1]
# ['ei', 1]
# ['el', 1]
# ['eletta', 3]
# ['eletto', 3]
# ['elezione', 6]
# ['elice', 1]
# ['eliodoro', 6]
# ['eliso', 3]
# ['elitropia', 6]
# ['ella', 1]
# ['elle', 1]
# ['ellera', 1]
# ['elli', 1]
# ['ello', 1]
# ['elsa', 1]
# ['emisperio', 6]
# ['emme', 1]
# ['empio', 1]
# ['empireo', 4]
# ['enigma', 3]
# ['entrata', 5]
# ['entro', 1]
# ['epa', 1]
# ['epiciclo', 5]
# ['equale', 4]
# ['equalità', 8]
# ['equatore', 6]
# ['era', 1]
# ['erba', 1]
# ['erbetta', 4]
# ['eretto', 3]
# ['ermafrodito', 9]
# ['ermo', 1]
# ['errante', 4]
# ['errore', 4]
# ['erta', 1]
# ['erto', 1]
# ['esca', 1]
# ['esperienza', 7]
# ['esperto', 4]
# ['espresso', 5]
# ['esse', 1]
# ['essemplo', 4]
# ['essenza', 4]
# ['essercito', 4]
# ['essere', 1]
# ['essilio', 4]
# ['esso', 1]
# ['est', 1]
# ['estimo', 1]
# ['esto', 1]
# ['estrema', 5]
# ['estremità', 9]
# ['et', 1]
# ['etade', 3]
# ['etate', 3]
# ['etera', 3]
# ['etica', 1]
# ['etico', 1]
# ['età', 3]
# ['euro', 1]
# ['evangelico', 6]
# ['evangelio', 6]
# ['fabbro', 2]
# ['faccia', 2]
# ['face', 2]
# ['facella', 4]
# ['facultade', 7]
# ['facultate', 7]
# ['faenza', 3]
# ['falca', 2]
# ['falcone', 5]
# ['falconiere', 8]
# ['falla', 2]
# ['fallace', 5]
# ['fallanza', 5]
# ['fallire', 5]
# ['fallo', 2]
# ['falsamente', 7]
# ['falsificare', 9]
# ['falsificato', 9]
# ['falsità', 7]
# ['falso', 2]
# ['fama', 2]
# ['fame', 2]
# ['famiglia', 4]
# ['famoso', 4]
# ['fanciullo', 6]
# ['fango', 2]
# ['fano', 2]
# ['fantasia', 7]
# ['fante', 2]
# ['fantolino', 7]
# ['fare', 2]
# ['farfalla', 5]
# ['farina', 4]
# ['farinata', 6]
# ['fascia', 2]
# ['fasciato', 6]
# ['fascio', 2]
# ['fata', 2]
# ['fatale', 4]
# ['fatica', 4]
# ['faticoso', 6]
# ['fato', 2]
# ['fatta', 2]
# ['fatto', 2]
# ['fattore', 5]
# ['fattura', 5]
# ['fatturo', 5]
# ['fausto', 2]
# ['favella', 4]
# ['favilla', 4]
# ['favola', 2]
# ['favoleggiare', 10]
# ['febbre', 2]
# ['feci', 2]
# ['fede', 2]
# ['fedele', 4]
# ['fedire', 4]
# ['fele', 2]
# ['felice', 4]
# ['felicità', 8]
# ['felle', 2]
# ['fello', 2]
# ['fellonia', 7]
# ['feltro', 2]
# ['femmina', 2]
# ['femminetta', 7]
# ['fenestra', 4]
# ['fenice', 4]
# ['fera', 2]
# ['ferace', 4]
# ['feria', 2]
# ['ferita', 4]
# ['ferma', 2]
# ['fermato', 5]
# ['fermi', 2]
# ['fermo', 2]
# ['fero', 2]
# ['feroce', 4]
# ['ferrarese', 7]
# ['ferrigno', 5]
# ['ferro', 2]
# ['fersa', 2]
# ['fertile', 2]
# ['fervore', 5]
# ['ferza', 2]
# ['fessa', 2]
# ['fesso', 2]
# ['fessura', 5]
# ['festa', 2]
# ['festino', 5]
# ['festuca', 5]
# ['feto', 2]
# ['fiacca', 3]
# ['fiacco', 3]
# ['fiala', 3]
# ['fiamma', 3]
# ['fiammeggiante', 10]
# ['fiammeggiare', 10]
# ['fiammella', 6]
# ['fianco', 3]
# ['fiata', 3]
# ['fiato', 3]
# ['fico', 2]
# ['fida', 2]
# ['fidanza', 4]
# ['fiele', 3]
# ['fieno', 3]
# ['fiera', 3]
# ['fieramente', 7]
# ['fiero', 3]
# ['fievole', 3]
# ['figlia', 2]
# ['figliastro', 6]
# ['figlio', 2]
# ['figliuolo', 7]
# ['figo', 2]
# ['figura', 4]
# ['figurato', 6]
# ['fila', 2]
# ['filippo', 4]
# ['filo', 2]
# ['filosofia', 8]
# ['fine', 2]
# ['finita', 4]
# ['finito', 4]
# ['fino', 2]
# ['fio', 2]
# ['fiocca', 3]
# ['fioco', 3]
# ['fiordaliso', 8]
# ['fiore', 3]
# ['fiorentina', 8]
# ['fiorentino', 8]
# ['fiorenza', 5]
# ['fiori', 3]
# ['fiotto', 3]
# ['fischio', 6]
# ['fisica', 2]
# ['fiso', 2]
# ['fissa', 2]
# ['fisso', 2]
# ['fitta', 2]
# ['fittizio', 5]
# ['fitto', 2]
# ['fiumana', 5]
# ['fiume', 3]
# ['flagello', 5]
# ['fleto', 3]
# ['focaccia', 4]
# ['foce', 2]
# ['focile', 4]
# ['foga', 2]
# ['foggia', 2]
# ['foglia', 2]
# ['foglio', 2]
# ['folgore', 2]
# ['folle', 2]
# ['folletto', 5]
# ['follia', 5]
# ['folta', 2]
# ['folto', 2]
# ['fonda', 2]
# ['fondamento', 7]
# ['fondo', 2]
# ['fontana', 5]
# ['fonte', 2]
# ['fora', 2]
# ['forame', 4]
# ['forato', 4]
# ['forca', 2]
# ['forcata', 5]
# ['force', 2]
# ['forcuto', 5]
# ['fore', 2]
# ['forese', 4]
# ['foresta', 4]
# ['fori', 2]
# ['forma', 2]
# ['formale', 5]
# ['formica', 5]
# ['fornace', 5]
# ['fornito', 5]
# ['foro', 2]
# ['forse', 2]
# ['forte', 2]
# ['fortezza', 5]
# ['fortuna', 5]
# ['forza', 2]
# ['fosco', 2]
# ['fossa', 2]
# ['fossato', 5]
# ['fosso', 2]
# ['fracasso', 5]
# ['francesca', 6]
# ['francesco', 6]
# ['franchezza', 7]
# ['franco', 3]
# ['frasca', 3]
# ['fraschetta', 7]
# ['frate', 3]
# ['fratello', 5]
# ['fratta', 3]
# ['fratto', 3]
# ['freddo', 3]
# ['freddura', 6]
# ['fregio', 3]
# ['frequentato', 9]
# ['frequente', 6]
# ['fresco', 3]
# ['fretta', 3]
# ['froda', 3]
# ['frode', 3]
# ['fronda', 3]
# ['fronde', 3]
# ['fronte', 3]
# ['frui', 3]
# ['frusto', 3]
# ['frustra', 3]
# ['frutta', 3]
# ['fruttare', 6]
# ['frutto', 3]
# ['fuga', 2]
# ['fuggire', 5]
# ['fulgore', 5]
# ['fulvido', 2]
# ['fummo', 2]
# ['fune', 2]
# ['fuoco', 3]
# ['fuori', 3]
# ['furare', 4]
# ['furia', 2]
# ['furo', 2]
# ['furore', 4]
# ['furto', 2]
# ['fuso', 2]
# ['fusto', 2]
# ['futa', 2]
# ['futuro', 4]
# ['gabbo', 2]
# ['gaia', 2]
# ['galassia', 4]
# ['galeoto', 5]
# ['galeotto', 5]
# ['galla', 2]
# ['gallo', 2]
# ['ganimede', 6]
# ['gardingo', 5]
# ['garofano', 4]
# ['gaudio', 2]
# ['gaudioso', 6]
# ['gel', 2]
# ['gelata', 4]
# ['gelatina', 6]
# ['gelato', 4]
# ['gelo', 2]
# ['gelso', 2]
# ['gemma', 2]
# ['gene', 2]
# ['genitrice', 7]
# ['gennaio', 5]
# ['genovese', 6]
# ['gente', 2]
# ['gentile', 5]
# ['gesta', 2]
# ['ghiaccia', 4]
# ['ghianda', 4]
# ['ghiotta', 4]
# ['ghiotto', 4]
# ['ghirlanda', 6]
# ['giacere', 5]
# ['giallo', 3]
# ['giano', 3]
# ['giardino', 6]
# ['gibbo', 2]
# ['gibetto', 4]
# ['giga', 2]
# ['gigante', 4]
# ['giglio', 2]
# ['gioco', 3]
# ['giocondo', 5]
# ['giogo', 3]
# ['gioia', 3]
# ['gioire', 4]
# ['giorno', 3]
# ['giostra', 3]
# ['giovane', 3]
# ['giovanetto', 7]
# ['giovare', 5]
# ['giovinetto', 7]
# ['giovinezza', 7]
# ['girare', 4]
# ['girato', 4]
# ['gire', 2]
# ['giro', 2]
# ['girone', 4]
# ['gita', 2]
# ['giubileo', 7]
# ['giuda', 3]
# ['giudecca', 5]
# ['giudeo', 5]
# ['giudicante', 7]
# ['giudice', 3]
# ['giudicio', 5]
# ['giudizio', 5]
# ['giugnere', 3]
# ['giunco', 3]
# ['giunta', 3]
# ['giunto', 3]
# ['giuntura', 6]
# ['giurato', 5]
# ['giuro', 3]
# ['giuso', 3]
# ['giusta', 3]
# ['giustamente', 8]
# ['giustizia', 6]
# ['giusto', 3]
# ['glauco', 3]
# ['gliene', 4]
# ['globo', 3]
# ['gloria', 3]
# ['glorioso', 6]
# ['goccia', 2]
# ['gola', 2]
# ['golfo', 2]
# ['gora', 2]
# ['gorgiera', 6]
# ['gorgo', 2]
# ['gota', 2]
# ['governo', 4]
# ['gozzo', 2]
# ['grada', 3]
# ['gradire', 5]
# ['grado', 3]
# ['gramigna', 5]
# ['gramo', 3]
# ['grande', 3]
# ['grandezza', 6]
# ['grandine', 3]
# ['grasso', 3]
# ['grata', 3]
# ['grato', 3]
# ['grava', 3]
# ['grave', 3]
# ['gravezza', 5]
# ['gravido', 3]
# ['grazia', 3]
# ['grazie', 3]
# ['grazioso', 6]
# ['greco', 3]
# ['gregge', 3]
# ['greggia', 3]
# ['grembo', 3]
# ['greppo', 3]
# ['greve', 3]
# ['grida', 3]
# ['gridare', 5]
# ['grido', 3]
# ['grifagno', 5]
# ['grifo', 3]
# ['grifone', 5]
# ['gromma', 3]
# ['gronda', 3]
# ['groppa', 3]
# ['groppo', 3]
# ['groppone', 6]
# ['grossa', 3]
# ['grosso', 3]
# ['grotta', 3]
# ['grue', 3]
# ['guada', 3]
# ['guado', 3]
# ['guai', 3]
# ['guaio', 3]
# ['gualdo', 3]
# ['guancia', 3]
# ['guanto', 3]
# ['guarda', 3]
# ['guardare', 6]
# ['guardata', 6]
# ['guardia', 3]
# ['guardo', 3]
# ['guari', 3]
# ['guasto', 3]
# ['guazzo', 3]
# ['guerra', 3]
# ['guida', 3]
# ['guisa', 3]
# ['guizzante', 6]
# ['guizzo', 3]
# ['gurge', 2]
# ['gusto', 2]
# ['iattanza', 5]
# ['iattura', 5]
# ['idea', 3]
# ['idioma', 4]
# ['idolo', 1]
# ['idropesì', 8]
# ['idropico', 4]
# ['igne', 1]
# ['ignito', 4]
# ['ignoranza', 6]
# ['illuminante', 8]
# ['illuminato', 8]
# ['image', 3]
# ['imagine', 3]
# ['imago', 3]
# ['immobile', 4]
# ['immortale', 7]
# ['imo', 1]
# ['impedimento', 8]
# ['impedito', 6]
# ['imperadore', 8]
# ['imperadrice', 9]
# ['imperio', 4]
# ['impero', 4]
# ['impeto', 1]
# ['impetrare', 7]
# ['impetuoso', 7]
# ['imposta', 4]
# ['imprenta', 5]
# ['impresa', 5]
# ['impresso', 5]
# ['inanzi', 3]
# ['incarco', 4]
# ['incendio', 4]
# ['incenso', 4]
# ['inceso', 4]
# ['incognita', 4]
# ['incognito', 4]
# ['incontanente', 9]
# ['incontra', 4]
# ['incontro', 4]
# ['incostro', 4]
# ['incredibile', 7]
# ['incude', 4]
# ['indaco', 1]
# ['indarno', 4]
# ['indegno', 4]
# ['indi', 1]
# ['indistinto', 7]
# ['indizio', 4]
# ['indo', 1]
# ['indugio', 4]
# ['ineffabile', 6]
# ['infallibile', 7]
# ['infamia', 4]
# ['infermo', 4]
# ['infernale', 7]
# ['inferno', 4]
# ['infiammato', 8]
# ['infimo', 1]
# ['infinito', 6]
# ['infino', 4]
# ['influenza', 6]
# ['informante', 7]
# ['informativa', 9]
# ['infra', 1]
# ['infuso', 4]
# ['inganno', 4]
# ['ingegno', 4]
# ['ingesto', 4]
# ['inghilese', 7]
# ['ingiuria', 5]
# ['ingiusto', 5]
# ['ingrato', 5]
# ['inizio', 3]
# ['innamorato', 8]
# ['innanzi', 4]
# ['inno', 1]
# ['innocente', 6]
# ['innocenza', 6]
# ['insano', 4]
# ['insegna', 4]
# ['insieme', 5]
# ['insino', 4]
# ['instanza', 5]
# ['intagliato', 8]
# ['intanto', 4]
# ['intelletto', 7]
# ['intelligenza', 9]
# ['intendente', 7]
# ['intento', 4]
# ['intenzione', 8]
# ['interciso', 7]
# ['interdetto', 7]
# ['interno', 4]
# ['intero', 4]
# ['intervallo', 7]
# ['intesa', 4]
# ['inteso', 4]
# ['intima', 1]
# ['intoppo', 4]
# ['intorno', 4]
# ['intra', 1]
# ['intrare', 5]
# ['intrata', 5]
# ['introcque', 5]
# ['invaghito', 7]
# ['inveggia', 4]
# ['inver', 4]
# ['inverno', 4]
# ['inverso', 4]
# ['invidia', 4]
# ['invio', 4]
# ['invito', 4]
# ['involto', 4]
# ['involuto', 6]
# ['io', 1]
# ['iole', 2]
# ['ipocresia', 8]
# ['ira', 1]
# ['iracundia', 5]
# ['irato', 3]
# ['ire', 1]
# ['iri', 1]
# ['isola', 1]
# ['isopo', 3]
# ['issa', 1]
# ['isso', 1]
# ['istinto', 4]
# ['istoria', 4]
# ['ito', 1]
# ['ivi', 1]
# ['labbia', 2]
# ['labore', 4]
# ['lacca', 2]
# ['lacerto', 4]
# ['laci', 2]
# ['laco', 2]
# ['lacuna', 4]
# ['ladro', 2]
# ['ladroneccio', 7]
# ['lagna', 2]
# ['lagnarsi', 5]
# ['lago', 2]
# ['lai', 2]
# ['laico', 2]
# ['lama', 2]
# ['lamento', 4]
# ['lampa', 2]
# ['lampo', 2]
# ['lance', 2]
# ['lancia', 2]
# ['landa', 2]
# ['lano', 2]
# ['lanterna', 5]
# ['larga', 2]
# ['larghezza', 6]
# ['largo', 2]
# ['lasca', 2]
# ['lasciare', 6]
# ['lasciata', 6]
# ['lasciato', 6]
# ['lascio', 2]
# ['lascivo', 5]
# ['lassa', 2]
# ['lassi', 2]
# ['lasso', 2]
# ['latente', 4]
# ['latino', 4]
# ['lato', 2]
# ['latria', 5]
# ['latte', 2]
# ['laudabile', 5]
# ['laude', 2]
# ['lauro', 2]
# ['lava', 2]
# ['lavina', 4]
# ['lavorare', 6]
# ['lavoro', 4]
# ['le', 2]
# ['leandro', 3]
# ['lebbroso', 6]
# ['lega', 2]
# ['legame', 4]
# ['legata', 4]
# ['legato', 4]
# ['legge', 2]
# ['leggera', 5]
# ['leggero', 5]
# ['leggiadria', 9]
# ['legista', 4]
# ['legna', 2]
# ['legno', 2]
# ['lego', 2]
# ['lei', 2]
# ['lembo', 2]
# ['lena', 2]
# ['leno', 2]
# ['lente', 2]
# ['lento', 2]
# ['leone', 3]
# ['leonessa', 5]
# ['leppo', 2]
# ['letame', 4]
# ['letargo', 4]
# ['letizia', 4]
# ['letta', 2]
# ['letto', 2]
# ['lettore', 5]
# ['lettura', 5]
# ['leva', 2]
# ['levante', 4]
# ['levata', 4]
# ['levato', 4]
# ['leve', 2]
# ['lezione', 5]
# ['lezzo', 2]
# ['libano', 4]
# ['libente', 4]
# ['liberamente', 8]
# ['libero', 2]
# ['libertate', 7]
# ['libertà', 7]
# ['libito', 2]
# ['libra', 2]
# ['libro', 2]
# ['licenza', 4]
# ['lici', 2]
# ['licito', 2]
# ['lieto', 3]
# ['lieve', 3]
# ['lievemente', 7]
# ['lilla', 2]
# ['lima', 2]
# ['limbo', 2]
# ['limo', 2]
# ['linci', 2]
# ['lingua', 2]
# ['linguaggio', 6]
# ['lino', 2]
# ['liquor', 2]
# ['lira', 2]
# ['liscia', 2]
# ['lista', 2]
# ['lite', 2]
# ['lito', 2]
# ['livido', 2]
# ['livore', 4]
# ['lo', 2]
# ['loco', 2]
# ['loda', 2]
# ['lode', 2]
# ['lodo', 2]
# ['loglio', 2]
# ['logoro', 2]
# ['loico', 2]
# ['lombarda', 5]
# ['lombardo', 5]
# ['longobardo', 7]
# ['lontano', 5]
# ['lontra', 2]
# ['lonza', 2]
# ['loquela', 5]
# ['lordo', 2]
# ['lordura', 5]
# ['loro', 2]
# ['loto', 2]
# ['lucano', 4]
# ['luce', 2]
# ['lucente', 4]
# ['lucerna', 4]
# ['lucia', 4]
# ['lucido', 2]
# ['lucifero', 4]
# ['lucore', 4]
# ['ludo', 2]
# ['luglio', 2]
# ['lui', 2]
# ['luigi', 3]
# ['lulla', 2]
# ['lume', 2]
# ['lumera', 4]
# ['luminoso', 6]
# ['luna', 2]
# ['lunga', 2]
# ['lungamente', 7]
# ['lunge', 2]
# ['lunghesso', 6]
# ['lunghezza', 6]
# ['lungi', 2]
# ['lungo', 2]
# ['luogo', 3]
# ['lupa', 2]
# ['lupo', 2]
# ['lussuria', 5]
# ['lustra', 2]
# ['lustro', 2]
# ['lutto', 2]
# ['macigno', 4]
# ['maciulla', 5]
# ['macro', 2]
# ['madonna', 4]
# ['madre', 2]
# ['magagna', 4]
# ['maggio', 2]
# ['maggiore', 6]
# ['magnanimo', 5]
# ['magnificenza', 9]
# ['magnifico', 5]
# ['magno', 2]
# ['mago', 2]
# ['magra', 2]
# ['magrezza', 5]
# ['magro', 2]
# ['mai', 2]
# ['maiolica', 4]
# ['mala', 2]
# ['malagevole', 6]
# ['malanno', 4]
# ['male', 2]
# ['maligno', 4]
# ['malizia', 4]
# ['malizioso', 7]
# ['malmenare', 7]
# ['malo', 2]
# ['malta', 2]
# ['malvagia', 7]
# ['malvagio', 5]
# ['mamma', 2]
# ['mammella', 5]
# ['mancia', 2]
# ['mancina', 5]
# ['mancino', 5]
# ['manco', 2]
# ['mandato', 5]
# ['mandra', 2]
# ['mane', 2]
# ['maniera', 5]
# ['manifesto', 6]
# ['manna', 2]
# ['mano', 2]
# ['mantaco', 2]
# ['manto', 2]
# ['marca', 2]
# ['marchese', 6]
# ['marcia', 2]
# ['marco', 2]
# ['mare', 2]
# ['mareggiare', 8]
# ['maremma', 4]
# ['margarita', 7]
# ['margherita', 8]
# ['marina', 4]
# ['marino', 4]
# ['marito', 4]
# ['marmo', 2]
# ['marra', 2]
# ['martello', 5]
# ['martino', 5]
# ['martiro', 5]
# ['mascella', 5]
# ['maschio', 2]
# ['masnada', 5]
# ['mastino', 5]
# ['mastro', 2]
# ['matera', 4]
# ['materia', 4]
# ['materno', 4]
# ['matre', 2]
# ['matrimonio', 7]
# ['matta', 2]
# ['mattia', 5]
# ['mattina', 5]
# ['mattino', 5]
# ['matto', 2]
# ['maturo', 4]
# ['me', 2]
# ['meco', 2]
# ['medesimo', 4]
# ['medesmo', 4]
# ['medicina', 6]
# ['medusa', 4]
# ['megera', 4]
# ['meglio', 2]
# ['mei', 2]
# ['mele', 2]
# ['melo', 2]
# ['melode', 4]
# ['melodia', 6]
# ['membro', 2]
# ['membruto', 6]
# ['memoria', 4]
# ['mena', 2]
# ['menare', 4]
# ['mencio', 2]
# ['meno', 2]
# ['mensa', 2]
# ['mensola', 2]
# ['mente', 2]
# ['mentire', 5]
# ['mento', 2]
# ['mentre', 2]
# ['menzogna', 5]
# ['mercatante', 7]
# ['mercato', 5]
# ['merce', 2]
# ['mercede', 5]
# ['mercurio', 5]
# ['merda', 2]
# ['meretrice', 7]
# ['meridiana', 7]
# ['meridiano', 7]
# ['meritare', 6]
# ['merito', 2]
# ['meritorio', 6]
# ['merlo', 2]
# ['mero', 2]
# ['merto', 2]
# ['mese', 2]
# ['messa', 2]
# ['messe', 2]
# ['messo', 2]
# ['mestiere', 6]
# ['mestieri', 6]
# ['meta', 2]
# ['metallo', 4]
# ['metro', 2]
# ['metropolitano', 11]
# ['mettere', 2]
# ['mezzana', 5]
# ['mezzo', 2]
# ['mia', 2]
# ['mida', 2]
# ['migliaio', 6]
# ['migliore', 6]
# ['milia', 2]
# ['militante', 6]
# ['milizia', 4]
# ['mille', 2]
# ['millesmo', 5]
# ['minaccia', 4]
# ['minerva', 4]
# ['ministero', 7]
# ['ministra', 4]
# ['ministro', 4]
# ['minore', 4]
# ['minotauro', 6]
# ['minugia', 4]
# ['mio', 2]
# ['mira', 2]
# ['mirabile', 4]
# ['mirabilmente', 9]
# ['miraglio', 4]
# ['mirando', 4]
# ['mirare', 4]
# ['miro', 2]
# ['mirra', 2]
# ['mirto', 2]
# ['mischia', 2]
# ['mischiata', 7]
# ['mischio', 2]
# ['miseramente', 8]
# ['miserere', 6]
# ['miseria', 4]
# ['misericordia', 8]
# ['misero', 2]
# ['miso', 2]
# ['mista', 2]
# ['misto', 2]
# ['mistura', 5]
# ['misura', 4]
# ['misuratamente', 10]
# ['mite', 2]
# ['mo', 2]
# ['mobile', 2]
# ['moderno', 4]
# ['modo', 2]
# ['moglie', 2]
# ['mola', 2]
# ['molesto', 4]
# ['molle', 2]
# ['moltitudine', 7]
# ['molto', 2]
# ['monastero', 7]
# ['monda', 2]
# ['mondana', 5]
# ['mondano', 5]
# ['mondiglia', 5]
# ['mondizia', 5]
# ['mondo', 2]
# ['moneta', 4]
# ['monta', 2]
# ['montagna', 5]
# ['montanaro', 7]
# ['montare', 5]
# ['monte', 2]
# ['montone', 5]
# ['mora', 2]
# ['morale', 4]
# ['moralità', 8]
# ['moralmente', 7]
# ['mordere', 2]
# ['moria', 4]
# ['morire', 4]
# ['mormorare', 7]
# ['morsa', 2]
# ['morso', 2]
# ['morta', 2]
# ['mortale', 5]
# ['mortalità', 9]
# ['morte', 2]
# ['morto', 2]
# ['mosca', 2]
# ['mossa', 2]
# ['mosso', 2]
# ['mostra', 2]
# ['mostro', 2]
# ['mota', 2]
# ['moto', 2]
# ['motto', 2]
# ['mozza', 2]
# ['mozzo', 2]
# ['mucchio', 2]
# ['muda', 2]
# ['muffa', 2]
# ['muno', 2]
# ['muovere', 3]
# ['mura', 2]
# ['muro', 2]
# ['musa', 2]
# ['muso', 2]
# ['muta', 2]
# ['mutamento', 6]
# ['mutare', 4]
# ['muto', 2]
# ['mutua', 2]
# ['naiade', 2]
# ['nanna', 2]
# ['narcisso', 5]
# ['nardo', 2]
# ['nascente', 5]
# ['nascere', 2]
# ['nascosto', 5]
# ['naso', 2]
# ['nastro', 2]
# ['nasuto', 4]
# ['natio', 4]
# ['nato', 2]
# ['natura', 4]
# ['naturale', 6]
# ['naturalmente', 9]
# ['navarrese', 7]
# ['nave', 2]
# ['navicella', 6]
# ['navigio', 4]
# ['nazione', 5]
# ['ne', 2]
# ['nebbia', 2]
# ['nebulosa', 6]
# ['necessario', 7]
# ['necesse', 4]
# ['necessitato', 9]
# ['necessità', 9]
# ['neente', 3]
# ['negato', 4]
# ['negghienza', 7]
# ['negletto', 5]
# ['negligente', 7]
# ['negligenza', 7]
# ['nego', 2]
# ['negozio', 4]
# ['nei', 2]
# ['nel', 2]
# ['nella', 2]
# ['nemico', 4]
# ['nepote', 4]
# ['nequizia', 5]
# ['nera', 2]
# ['nerbo', 2]
# ['nero', 2]
# ['nessuno', 5]
# ['nettare', 5]
# ['neve', 2]
# ['nicchia', 2]
# ['nido', 2]
# ['niego', 3]
# ['niente', 3]
# ['nimico', 4]
# ['nino', 2]
# ['no', 2]
# ['nobile', 2]
# ['nobiltà', 7]
# ['nocchiere', 7]
# ['nocchiero', 7]
# ['noce', 2]
# ['nocera', 4]
# ['nocivo', 4]
# ['nodo', 2]
# ['noi', 2]
# ['noia', 2]
# ['noma', 2]
# ['nome', 2]
# ['nominanza', 6]
# ['non', 2]
# ['nona', 2]
# ['nondimeno', 7]
# ['nono', 2]
# ['nonpossa', 5]
# ['norma', 2]
# ['nosco', 2]
# ['nostro', 2]
# ['nota', 2]
# ['notabile', 4]
# ['notaro', 4]
# ['notizia', 4]
# ['noto', 2]
# ['notte', 2]
# ['notturna', 5]
# ['notturno', 5]
# ['nova', 2]
# ['nove', 2]
# ['novecento', 6]
# ['novella', 4]
# ['novello', 4]
# ['novembre', 4]
# ['noverca', 4]
# ['novissimo', 4]
# ['novità', 6]
# ['novo', 2]
# ['nozze', 2]
# ['nube', 2]
# ['nuca', 2]
# ['nudo', 2]
# ['nulla', 2]
# ['nullo', 2]
# ['numero', 2]
# ['nuova', 3]
# ['nuovo', 3]
# ['nuro', 2]
# ['nutrice', 5]
# ['nuvola', 2]
# ['nuvoletta', 6]
# ['obbrobrio', 5]
# ['obietto', 4]
# ['oblio', 4]
# ['oca', 1]
# ['occaso', 4]
# ['occhio', 1]
# ['occidente', 6]
# ['occulto', 4]
# ['od', 1]
# ['oda', 1]
# ['ode', 1]
# ['odiare', 4]
# ['odierno', 4]
# ['odio', 1]
# ['offensa', 4]
# ['offensione', 8]
# ['offerere', 6]
# ['offerta', 4]
# ['offesa', 4]
# ['offeso', 4]
# ['officio', 4]
# ['oggi', 1]
# ['oggimai', 6]
# ['ogni', 1]
# ['ognora', 4]
# ['ognuno', 4]
# ['ohi', 1]
# ['olocausto', 5]
# ['oltra', 1]
# ['oltracotanza', 9]
# ['oltraggio', 5]
# ['oltre', 1]
# ['om', 1]
# ['omai', 3]
# ['ombra', 1]
# ['omero', 1]
# ['omo', 1]
# ['oncia', 1]
# ['onda', 1]
# ['onde', 1]
# ['onestade', 6]
# ['onesto', 3]
# ['onore', 3]
# ['onranza', 4]
# ['onta', 1]
# ['ontoso', 4]
# ['opera', 1]
# ['operando', 5]
# ['operante', 5]
# ['operare', 5]
# ['opimo', 3]
# ['oppinione', 7]
# ['opposito', 4]
# ['opposizione', 9]
# ['oppresso', 5]
# ['opra', 1]
# ['or', 1]
# ['ora', 1]
# ['oramai', 5]
# ['orazione', 6]
# ['orbita', 1]
# ['orbo', 1]
# ['ordigno', 4]
# ['ordine', 1]
# ['orecchia', 3]
# ['orezza', 3]
# ['organo', 1]
# ['orgoglio', 4]
# ['oriafiamma', 7]
# ['oriente', 4]
# ['orizzonta', 6]
# ['orizzonte', 6]
# ['orlo', 1]
# ['orma', 1]
# ['ormai', 4]
# ['oro', 1]
# ['orologio', 5]
# ['orribile', 4]
# ['orribilmente', 9]
# ['orsa', 1]
# ['orso', 1]
# ['ortica', 4]
# ['orto', 1]
# ['ortolano', 6]
# ['orza', 1]
# ['osanna', 3]
# ['oscuro', 4]
# ['oso', 1]
# ['ospizio', 4]
# ['ossame', 4]
# ['osso', 1]
# ['ostante', 4]
# ['ostello', 4]
# ['ostiense', 5]
# ['otta', 1]
# ['ottava', 4]
# ['ottavo', 4]
# ['otto', 1]
# ['ottobre', 4]
# ['ove', 1]
# ['ovile', 3]
# ['ovra', 1]
# ['ovrare', 4]
# ['ozio', 1]
# ['pace', 2]
# ['pachino', 5]
# ['pado', 2]
# ['padre', 2]
# ['padrone', 5]
# ['paese', 3]
# ['paga', 2]
# ['paganesmo', 6]
# ['paglia', 2]
# ['paio', 2]
# ['paladino', 6]
# ['palagio', 4]
# ['palato', 4]
# ['palazzo', 4]
# ['paleo', 4]
# ['palese', 4]
# ['pali', 2]
# ['palladio', 5]
# ['palma', 2]
# ['palude', 4]
# ['pancia', 2]
# ['pane', 2]
# ['panno', 2]
# ['pantano', 5]
# ['papa', 2]
# ['papale', 4]
# ['papiro', 4]
# ['pappo', 2]
# ['paradiso', 6]
# ['parca', 2]
# ['parco', 2]
# ['pare', 2]
# ['parecchio', 4]
# ['pareggio', 4]
# ['parente', 4]
# ['parere', 4]
# ['parete', 4]
# ['pari', 2]
# ['parlamento', 7]
# ['parlare', 5]
# ['parlasia', 7]
# ['parlato', 5]
# ['parnaso', 5]
# ['paro', 2]
# ['paroffia', 4]
# ['parola', 4]
# ['parte', 2]
# ['partire', 5]
# ['partita', 5]
# ['partito', 5]
# ['parto', 2]
# ['paruta', 4]
# ['parvente', 5]
# ['parvenza', 5]
# ['parvo', 2]
# ['pasciuto', 6]
# ['pasco', 2]
# ['passa', 2]
# ['passaggio', 5]
# ['passare', 5]
# ['passato', 5]
# ['passeggiare', 9]
# ['passi', 2]
# ['passione', 6]
# ['passo', 2]
# ['pasto', 2]
# ['pastore', 5]
# ['pastura', 5]
# ['pasturale', 7]
# ['paterno', 4]
# ['paternostro', 7]
# ['patire', 4]
# ['patre', 2]
# ['patria', 2]
# ['patriarca', 6]
# ['patto', 2]
# ['paura', 3]
# ['pausa', 2]
# ['pavento', 4]
# ['pavimento', 6]
# ['pazienza', 5]
# ['pazzo', 2]
# ['peana', 3]
# ['pecca', 2]
# ['peccato', 5]
# ['peccatore', 7]
# ['pece', 2]
# ['pedagogo', 6]
# ['peggio', 2]
# ['peggiore', 6]
# ['pegola', 2]
# ['pel', 2]
# ['pelago', 2]
# ['pelato', 4]
# ['pelle', 2]
# ['pellicano', 7]
# ['pelo', 2]
# ['peltro', 2]
# ['pena', 2]
# ['pendente', 5]
# ['pendice', 5]
# ['pene', 2]
# ['penetrante', 7]
# ['penetrare', 7]
# ['penitenza', 6]
# ['penna', 2]
# ['pennecchio', 5]
# ['pennino', 5]
# ['pennuto', 5]
# ['pensamento', 7]
# ['pensata', 5]
# ['pensiero', 6]
# ['penso', 2]
# ['pensoso', 5]
# ['pentimento', 7]
# ['pepe', 2]
# ['per', 2]
# ['pera', 2]
# ['perciò', 6]
# ['percossa', 5]
# ['perdere', 2]
# ['perdonanza', 7]
# ['perdono', 5]
# ['perduto', 5]
# ['perfettamente', 10]
# ['perfetto', 5]
# ['perfezione', 8]
# ['perfido', 2]
# ['pergamo', 2]
# ['periclo', 4]
# ['periglio', 4]
# ['perire', 4]
# ['perizoma', 6]
# ['perla', 2]
# ['permesso', 5]
# ['permotore', 7]
# ['permutanza', 7]
# ['perpetua', 5]
# ['perso', 2]
# ['persona', 5]
# ['pertugio', 5]
# ['perverso', 5]
# ['però', 4]
# ['pesa', 2]
# ['pesca', 2]
# ['pesce', 2]
# ['peschiera', 7]
# ['peso', 2]
# ['peste', 2]
# ['petraia', 5]
# ['petrina', 5]
# ['petto', 2]
# ['piacente', 5]
# ['piacere', 5]
# ['piaga', 3]
# ['piaggia', 3]
# ['piana', 3]
# ['pianeta', 5]
# ['pianeto', 5]
# ['piangere', 3]
# ['piano', 3]
# ['pianta', 3]
# ['piantato', 6]
# ['pianto', 3]
# ['pianura', 5]
# ['piato', 3]
# ['piede', 3]
# ['piega', 3]
# ['piegare', 5]
# ['piego', 3]
# ['piena', 3]
# ['pienamente', 7]
# ['pieno', 3]
# ['pieta', 3]
# ['pietade', 5]
# ['pietate', 5]
# ['pietoso', 5]
# ['pietra', 3]
# ['pietà', 5]
# ['pigliare', 6]
# ['piglio', 2]
# ['pigrizia', 5]
# ['pila', 2]
# ['pilato', 4]
# ['piloso', 4]
# ['pina', 2]
# ['pineta', 4]
# ['pingue', 2]
# ['pinta', 2]
# ['pio', 2]
# ['pioggia', 3]
# ['piomba', 3]
# ['piombato', 6]
# ['piombo', 3]
# ['piorno', 3]
# ['piota', 3]
# ['piova', 3]
# ['pira', 2]
# ['pistola', 5]
# ['pittura', 5]
# ['piuma', 3]
# ['plaga', 3]
# ['plaustro', 3]
# ['plebe', 3]
# ['ploia', 3]
# ['poco', 2]
# ['podere', 4]
# ['podestate', 7]
# ['poema', 3]
# ['poesì', 5]
# ['poeta', 3]
# ['poggia', 2]
# ['poggio', 2]
# ['poi', 2]
# ['pola', 2]
# ['polenta', 4]
# ['polo', 2]
# ['polve', 2]
# ['polveroso', 7]
# ['pome', 2]
# ['pomo', 2]
# ['ponderoso', 7]
# ['pondo', 2]
# ['ponente', 4]
# ['ponte', 2]
# ['ponticello', 7]
# ['popolo', 2]
# ['poppa', 2]
# ['porco', 2]
# ['porfido', 2]
# ['porre', 2]
# ['porta', 2]
# ['portata', 5]
# ['portato', 5]
# ['portinaio', 7]
# ['porto', 2]
# ['portogallo', 7]
# ['posa', 2]
# ['posare', 4]
# ['posato', 4]
# ['poscia', 2]
# ['possa', 2]
# ['possanza', 5]
# ['posseduto', 7]
# ['possente', 5]
# ['possessivo', 8]
# ['possibile', 5]
# ['posta', 2]
# ['posto', 2]
# ['potenza', 4]
# ['potere', 4]
# ['potestate', 7]
# ['poverello', 6]
# ['povero', 2]
# ['povertà', 7]
# ['pozza', 2]
# ['pozzo', 2]
# ['prato', 3]
# ['prece', 3]
# ['precedente', 7]
# ['precinto', 5]
# ['preciso', 5]
# ['preco', 3]
# ['preconio', 5]
# ['preda', 3]
# ['predella', 5]
# ['predicare', 7]
# ['prefetto', 5]
# ['preghiera', 7]
# ['pregio', 3]
# ['pregione', 6]
# ['pregno', 3]
# ['prego', 3]
# ['prendere', 3]
# ['presa', 3]
# ['prescritto', 7]
# ['presente', 5]
# ['presenza', 5]
# ['pressa', 3]
# ['presso', 3]
# ['pressura', 6]
# ['presto', 3]
# ['presuntuoso', 9]
# ['prete', 3]
# ['preterito', 5]
# ['prezioso', 6]
# ['pria', 3]
# ['priego', 4]
# ['prima', 3]
# ['primaio', 5]
# ['primavera', 7]
# ['primiero', 6]
# ['primizia', 5]
# ['primo', 3]
# ['principato', 8]
# ['principe', 3]
# ['principio', 6]
# ['privato', 5]
# ['privilegio', 7]
# ['privo', 3]
# ['probo', 3]
# ['procaccia', 5]
# ['procedere', 5]
# ['procella', 5]
# ['processo', 5]
# ['proda', 3]
# ['prode', 3]
# ['prodotto', 5]
# ['produtto', 5]
# ['proferta', 5]
# ['professione', 9]
# ['profeta', 5]
# ['profetico', 5]
# ['profondo', 5]
# ['progenie', 5]
# ['prole', 3]
# ['promessa', 5]
# ['pronto', 3]
# ['prope', 3]
# ['proponimento', 9]
# ['proporzione', 9]
# ['proposito', 5]
# ['proposta', 5]
# ['proposto', 5]
# ['propriamente', 9]
# ['proprio', 3]
# ['prora', 3]
# ['prossimano', 8]
# ['prossimo', 3]
# ['protesi', 3]
# ['prova', 3]
# ['provedenza', 7]
# ['provenzale', 8]
# ['prudenza', 5]
# ['pruno', 3]
# ['pruova', 4]
# ['pubblico', 2]
# ['puerizia', 5]
# ['puglia', 2]
# ['pugliese', 6]
# ['pugna', 2]
# ['pugno', 2]
# ['pulcro', 2]
# ['pulita', 4]
# ['pulito', 4]
# ['punga', 2]
# ['punta', 2]
# ['punto', 2]
# ['puntura', 5]
# ['pupilla', 4]
# ['pure', 2]
# ['purga', 2]
# ['purgatorio', 7]
# ['purgo', 2]
# ['puro', 2]
# ['pusillo', 4]
# ['putta', 2]
# ['puttana', 5]
# ['puzza', 2]
# ['puzzo', 2]
# ['qu', 2]
# ['quaderno', 5]
# ['quadra', 3]
# ['quadrante', 6]
# ['quai', 3]
# ['qualche', 3]
# ['quale', 3]
# ['qualità', 7]
# ['qualunque', 5]
# ['quando', 3]
# ['quandunque', 6]
# ['quanto', 3]
# ['quantunque', 6]
# ['quare', 3]
# ['quarta', 3]
# ['quartana', 6]
# ['quarto', 3]
# ['quasi', 3]
# ['quatto', 3]
# ['quattro', 3]
# ['quei', 3]
# ['quelli', 3]
# ['quello', 3]
# ['quercia', 3]
# ['questi', 3]
# ['questo', 3]
# ['quia', 3]
# ['quici', 3]
# ['quiditate', 7]
# ['quiete', 4]
# ['quieto', 4]
# ['quinci', 3]
# ['quindi', 3]
# ['quinta', 3]
# ['quinto', 3]
# ['quiritta', 5]
# ['quiritto', 5]
# ['quisquilia', 7]
# ['quistione', 7]
# ['quivi', 3]
# ['quorum', 3]
# ['rabbia', 2]
# ['rabbioso', 6]
# ['raccolta', 5]
# ['raccolto', 5]
# ['raccomandato', 10]
# ['rada', 2]
# ['radice', 4]
# ['rado', 2]
# ['ragazzo', 4]
# ['raggiare', 6]
# ['raggio', 2]
# ['ragionamento', 9]
# ['ragionare', 7]
# ['ragionato', 7]
# ['ragione', 5]
# ['ragna', 2]
# ['rai', 2]
# ['raia', 2]
# ['ramarro', 4]
# ['rame', 2]
# ['ramo', 2]
# ['ramogna', 4]
# ['rampogna', 5]
# ['rampollo', 5]
# ['rana', 2]
# ['rancura', 5]
# ['randa', 2]
# ['rapina', 4]
# ['rappresentare', 11]
# ['raro', 2]
# ['rascia', 2]
# ['rassegna', 5]
# ['ratta', 2]
# ['rattento', 5]
# ['rattezza', 5]
# ['ratto', 2]
# ['razionabile', 7]
# ['re', 2]
# ['reale', 3]
# ['reame', 3]
# ['rebecca', 4]
# ['recettacolo', 7]
# ['reda', 2]
# ['reddita', 5]
# ['redire', 4]
# ['refrigerio', 7]
# ['refugio', 4]
# ['regalmente', 7]
# ['rege', 2]
# ['regge', 2]
# ['reggia', 2]
# ['regina', 4]
# ['regno', 2]
# ['regola', 2]
# ['reina', 3]
# ['religione', 7]
# ['remedio', 4]
# ['remo', 2]
# ['remoto', 4]
# ['rena', 2]
# ['rendere', 2]
# ['renduto', 5]
# ['reni', 2]
# ['reo', 2]
# ['repente', 4]
# ['repleto', 5]
# ['resistenza', 7]
# ['respetto', 5]
# ['resta', 2]
# ['restare', 5]
# ['restato', 5]
# ['retaggio', 4]
# ['rete', 2]
# ['retro', 2]
# ['retrorso', 5]
# ['retroso', 5]
# ['retta', 2]
# ['retto', 2]
# ['reverente', 6]
# ['reverenza', 6]
# ['rezzo', 2]
# ['rialto', 3]
# ['riarso', 3]
# ['ribaldo', 4]
# ['ribellante', 7]
# ['ricchezza', 6]
# ['ricco', 2]
# ['ricetta', 4]
# ['ricevuto', 6]
# ['richiamo', 6]
# ['ricolta', 4]
# ['ricolto', 4]
# ['riconoscenza', 9]
# ['riconoscere', 6]
# ['riconosciuto', 10]
# ['ricoperta', 6]
# ['ricordo', 4]
# ['ridente', 4]
# ['ridere', 2]
# ['ridire', 4]
# ['rifatto', 4]
# ['rifiuto', 5]
# ['riga', 2]
# ['rigagno', 4]
# ['rigido', 2]
# ['riguardare', 8]
# ['riguardo', 5]
# ['rima', 2]
# ['rimanente', 6]
# ['rimbalzo', 5]
# ['rimbombo', 5]
# ['rimembranza', 8]
# ['rimessa', 4]
# ['rimorso', 4]
# ['rimosso', 4]
# ['rimpalmare', 8]
# ['rimpetto', 5]
# ['rincalzo', 5]
# ['rinchiuso', 7]
# ['rintoppo', 5]
# ['rio', 2]
# ['ripa', 2]
# ['riparo', 4]
# ['ripieno', 5]
# ['riposato', 6]
# ['riposo', 4]
# ['riposto', 4]
# ['riprezzo', 5]
# ['risalire', 6]
# ['rischio', 2]
# ['risega', 4]
# ['risma', 2]
# ['riso', 2]
# ['rispetto', 5]
# ['risplendere', 6]
# ['rispondere', 5]
# ['risposta', 5]
# ['rissa', 2]
# ['ristoro', 5]
# ['ristretto', 6]
# ['ritegno', 4]
# ['ritenere', 6]
# ['ritorno', 4]
# ['ritrarre', 5]
# ['ritratto', 5]
# ['ritroso', 5]
# ['ritto', 2]
# ['riva', 2]
# ['rivedere', 6]
# ['rivera', 4]
# ['riverso', 4]
# ['rivestire', 7]
# ['riviera', 5]
# ['rivo', 2]
# ['rivolta', 4]
# ['rivolto', 4]
# ['roba', 2]
# ['robusto', 4]
# ['rocca', 2]
# ['roccia', 2]
# ['rocco', 2]
# ['roco', 2]
# ['roffia', 2]
# ['roggia', 2]
# ['roggio', 2]
# ['rogna', 2]
# ['romano', 4]
# ['rombo', 2]
# ['romeo', 4]
# ['ronca', 2]
# ['ronchione', 7]
# ['ronchioso', 7]
# ['rondinella', 7]
# ['rosa', 2]
# ['roso', 2]
# ['rosso', 2]
# ['rossore', 5]
# ['rosta', 2]
# ['rostro', 2]
# ['rota', 2]
# ['rotare', 4]
# ['rotta', 2]
# ['rotto', 2]
# ['rovente', 4]
# ['rozzo', 2]
# ['ruba', 2]
# ['rubare', 4]
# ['rubecchio', 4]
# ['rubesto', 4]
# ['rubinetto', 6]
# ['rubro', 2]
# ['rude', 2]
# ['rugiada', 5]
# ['runciglio', 5]
# ['ruota', 3]
# ['rupe', 2]
# ['ruscelletto', 8]
# ['ruscello', 5]
# ['ruvidamente', 8]
# ['sabbione', 6]
# ['sacca', 2]
# ['sacchetto', 6]
# ['sacco', 2]
# ['sacerdozio', 7]
# ['sacrato', 5]
# ['sacrificio', 7]
# ['sacro', 2]
# ['sacrosanto', 7]
# ['saetta', 3]
# ['saggio', 2]
# ['saglia', 2]
# ['sagrestia', 8]
# ['salda', 2]
# ['saldo', 2]
# ['sale', 2]
# ['salire', 4]
# ['salita', 4]
# ['saliva', 4]
# ['salma', 2]
# ['salmista', 5]
# ['salmo', 2]
# ['salmodia', 7]
# ['salterello', 7]
# ['salute', 4]
# ['salva', 2]
# ['salvamento', 7]
# ['salvatico', 5]
# ['salvazione', 8]
# ['salve', 2]
# ['salvo', 2]
# ['sampogna', 5]
# ['sanctus', 2]
# ['sangue', 2]
# ['sanguigno', 6]
# ['sanguinoso', 8]
# ['sanna', 2]
# ['sannuto', 5]
# ['sano', 2]
# ['santo', 2]
# ['sanza', 2]
# ['sapere', 4]
# ['sapienza', 5]
# ['sapore', 4]
# ['saputa', 4]
# ['sartore', 5]
# ['sasso', 2]
# ['satiro', 2]
# ['satollo', 4]
# ['saturno', 4]
# ['savere', 4]
# ['savio', 2]
# ['sazio', 2]
# ['sbarro', 3]
# ['sbigottito', 8]
# ['scabbia', 3]
# ['scaccia', 3]
# ['scala', 3]
# ['scaldata', 6]
# ['scaleo', 5]
# ['scaletta', 5]
# ['scaltro', 3]
# ['scampo', 3]
# ['scandalo', 3]
# ['scanno', 3]
# ['scarco', 3]
# ['scardova', 3]
# ['scarmiglione', 10]
# ['scarso', 3]
# ['scellerato', 8]
# ['scelta', 3]
# ['scemata', 5]
# ['scemo', 3]
# ['scempio', 3]
# ['scendere', 3]
# ['scesa', 3]
# ['scheggia', 4]
# ['scheggio', 4]
# ['scherma', 4]
# ['schermo', 4]
# ['schiatta', 5]
# ['schiena', 5]
# ['schiera', 5]
# ['schietto', 5]
# ['schifo', 4]
# ['schiuma', 5]
# ['schiuso', 5]
# ['schivo', 4]
# ['sciagurato', 8]
# ['sciancato', 7]
# ['scienza', 4]
# ['scilocco', 5]
# ['scimia', 3]
# ['scintilla', 6]
# ['sciolta', 4]
# ['sciolto', 4]
# ['scisma', 3]
# ['scisso', 3]
# ['scocca', 3]
# ['scoglio', 3]
# ['scola', 3]
# ['sconcio', 3]
# ['sconoscente', 8]
# ['scoperta', 5]
# ['scoppio', 3]
# ['scorgere', 3]
# ['scorno', 3]
# ['scorpio', 3]
# ['scorta', 3]
# ['scosso', 3]
# ['scotto', 3]
# ['scranna', 4]
# ['scriba', 4]
# ['scritta', 4]
# ['scritto', 4]
# ['scrittura', 7]
# ['scrivere', 4]
# ['scrivo', 4]
# ['scrofa', 4]
# ['scroscio', 4]
# ['scudo', 3]
# ['scuola', 4]
# ['scuriada', 6]
# ['scuro', 3]
# ['scusa', 3]
# ['sdegnoso', 6]
# ['se', 2]
# ['secca', 2]
# ['secchezza', 6]
# ['secco', 2]
# ['seco', 2]
# ['secolo', 2]
# ['seconda', 4]
# ['secondo', 4]
# ['secreta', 5]
# ['secreto', 5]
# ['secure', 4]
# ['sedere', 4]
# ['sedia', 2]
# ['seggio', 2]
# ['segnare', 5]
# ['segnato', 5]
# ['segno', 2]
# ['sego', 2]
# ['segreta', 5]
# ['segretamente', 9]
# ['seguace', 5]
# ['seguente', 5]
# ['seguentemente', 10]
# ['seguire', 5]
# ['seguitare', 7]
# ['sei', 2]
# ['sella', 2]
# ['selva', 2]
# ['selvaggio', 5]
# ['sembiante', 6]
# ['sembianza', 6]
# ['seme', 2]
# ['sementa', 4]
# ['semente', 4]
# ['semenza', 4]
# ['seminata', 6]
# ['sempiterno', 7]
# ['semplice', 2]
# ['sempre', 2]
# ['sene', 2]
# ['senna', 2]
# ['senno', 2]
# ['seno', 2]
# ['sensato', 5]
# ['sensibile', 5]
# ['sensibilmente', 10]
# ['senso', 2]
# ['sentenza', 5]
# ['sentenzia', 5]
# ['sentiero', 6]
# ['sentimento', 7]
# ['sentire', 5]
# ['sentita', 5]
# ['sentito', 5]
# ['sepolto', 4]
# ['sepulcro', 4]
# ['sepultura', 7]
# ['ser', 2]
# ['sera', 2]
# ['serafico', 4]
# ['serena', 4]
# ['sereno', 4]
# ['sermo', 2]
# ['sermone', 5]
# ['serocchia', 4]
# ['serpente', 5]
# ['serpentello', 8]
# ['serra', 2]
# ['serrame', 5]
# ['serrare', 5]
# ['serrata', 5]
# ['serrato', 5]
# ['serto', 2]
# ['serva', 2]
# ['servigio', 5]
# ['servo', 2]
# ['sessanta', 5]
# ['sesta', 2]
# ['sesto', 2]
# ['seta', 2]
# ['sete', 2]
# ['setta', 2]
# ['sette', 2]
# ['settembre', 5]
# ['settima', 2]
# ['settimo', 2]
# ['severo', 4]
# ['sezzo', 2]
# ['sferza', 3]
# ['sfinge', 3]
# ['sfogato', 5]
# ['sfoglia', 3]
# ['sguardo', 4]
# ['sia', 2]
# ['sibilla', 4]
# ['sicura', 4]
# ['sicuramente', 8]
# ['sicuro', 4]
# ['sicurtà', 7]
# ['sie', 2]
# ['siepe', 3]
# ['sigillo', 4]
# ['signaculo', 5]
# ['silenzio', 4]
# ['silvano', 5]
# ['silvestro', 5]
# ['silvio', 2]
# ['similitudine', 8]
# ['similmente', 7]
# ['simonia', 6]
# ['sincero', 5]
# ['sine', 2]
# ['sinfonia', 7]
# ['sinistra', 4]
# ['sinistro', 4]
# ['sipa', 2]
# ['sire', 2]
# ['siringa', 4]
# ['sito', 2]
# ['smagato', 5]
# ['smalto', 3]
# ['smarrito', 6]
# ['smeraldo', 5]
# ['smisurato', 7]
# ['smorto', 3]
# ['soave', 3]
# ['soavemente', 7]
# ['soavità', 7]
# ['soccorso', 5]
# ['socero', 2]
# ['sodalizio', 6]
# ['sodo', 2]
# ['sofferto', 5]
# ['soffiata', 6]
# ['soffrire', 6]
# ['sofista', 4]
# ['soga', 2]
# ['soggiogare', 8]
# ['soggiorno', 6]
# ['soglia', 2]
# ['sogliare', 6]
# ['soglio', 2]
# ['sognare', 5]
# ['sogno', 2]
# ['sol', 2]
# ['sola', 2]
# ['solaio', 4]
# ['solamente', 6]
# ['solco', 2]
# ['soldano', 5]
# ['sole', 2]
# ['solecchio', 4]
# ['solere', 4]
# ['soletta', 4]
# ['soletto', 4]
# ['solfo', 2]
# ['solingo', 4]
# ['sollazzo', 5]
# ['sollo', 2]
# ['solo', 2]
# ['solone', 4]
# ['soluto', 4]
# ['soma', 2]
# ['somigliante', 8]
# ['somma', 2]
# ['sommerso', 5]
# ['sommo', 2]
# ['sonar', 2]
# ['sonno', 2]
# ['sonnolento', 7]
# ['sonnolenza', 7]
# ['soppressa', 6]
# ['soppresso', 6]
# ['sopra', 2]
# ['sopranome', 7]
# ['sor', 2]
# ['sorco', 2]
# ['sorella', 4]
# ['sorpresa', 6]
# ['sorpreso', 6]
# ['sorriso', 5]
# ['sorte', 2]
# ['sortita', 5]
# ['sospeccioso', 9]
# ['sospeso', 5]
# ['sospetto', 5]
# ['sospinto', 5]
# ['sospiro', 5]
# ['sosta', 2]
# ['sostegno', 5]
# ['sottesso', 5]
# ['sottile', 5]
# ['sottilmente', 8]
# ['sotto', 2]
# ['sottosopra', 7]
# ['sovente', 4]
# ['soverchio', 4]
# ['sovra', 2]
# ['sovrano', 5]
# ['sovresso', 5]
# ['sozzo', 2]
# ['spada', 3]
# ['spago', 3]
# ['spalla', 3]
# ['spanna', 3]
# ['sparso', 3]
# ['sparto', 3]
# ['spaventato', 8]
# ['spavento', 5]
# ['spazio', 3]
# ['spazzo', 3]
# ['specchia', 3]
# ['specchiato', 8]
# ['specchio', 3]
# ['specie', 3]
# ['specifica', 5]
# ['spedito', 5]
# ['speglio', 3]
# ['spelonca', 5]
# ['spelta', 3]
# ['speme', 3]
# ['spendere', 3]
# ['spene', 3]
# ['spento', 3]
# ['spera', 3]
# ['speranza', 5]
# ['spergiuro', 7]
# ['spesa', 3]
# ['spesso', 3]
# ['spezie', 3]
# ['spezzato', 6]
# ['spia', 3]
# ['spiacente', 6]
# ['spietato', 6]
# ['spiga', 3]
# ['spira', 3]
# ['spirare', 5]
# ['spiritale', 7]
# ['spirito', 3]
# ['spiro', 3]
# ['spirto', 3]
# ['splendido', 4]
# ['splendore', 7]
# ['spoglia', 3]
# ['sponda', 3]
# ['sposa', 3]
# ['sposo', 3]
# ['spranga', 4]
# ['sprazzo', 4]
# ['spugna', 3]
# ['squadro', 4]
# ['squama', 4]
# ['squilla', 4]
# ['stabilito', 7]
# ['stagione', 6]
# ['stagna', 3]
# ['stagno', 3]
# ['staio', 3]
# ['stallo', 3]
# ['stamane', 5]
# ['stampa', 3]
# ['stanca', 3]
# ['stanco', 3]
# ['stante', 3]
# ['stanza', 3]
# ['stare', 3]
# ['state', 3]
# ['stato', 3]
# ['statuto', 5]
# ['stazio', 3]
# ['stella', 3]
# ['stelo', 3]
# ['sterco', 3]
# ['stesso', 3]
# ['stile', 3]
# ['stilla', 3]
# ['stilo', 3]
# ['stima', 3]
# ['stimativa', 7]
# ['stimo', 3]
# ['stimolo', 3]
# ['stipa', 3]
# ['stizzo', 3]
# ['sto', 3]
# ['stola', 3]
# ['stoltezza', 6]
# ['stolto', 3]
# ['storia', 3]
# ['stormire', 6]
# ['stormo', 3]
# ['storpio', 3]
# ['stoscio', 3]
# ['strada', 4]
# ['strale', 4]
# ['strame', 4]
# ['strano', 4]
# ['strazio', 4]
# ['strega', 4]
# ['stregghia', 4]
# ['stremo', 4]
# ['stretta', 4]
# ['stretto', 4]
# ['stringa', 4]
# ['striscia', 4]
# ['strozza', 4]
# ['studio', 3]
# ['stuolo', 4]
# ['stupendo', 5]
# ['stupido', 3]
# ['stupor', 5]
# ['stupore', 5]
# ['subietto', 5]
# ['subitamente', 8]
# ['succhio', 2]
# ['sucidume', 6]
# ['suco', 2]
# ['suddito', 2]
# ['sudore', 4]
# ['sue', 2]
# ['sufficiente', 8]
# ['suggello', 5]
# ['suggetto', 5]
# ['sui', 2]
# ['summo', 2]
# ['suo', 2]
# ['suocero', 3]
# ['suolo', 3]
# ['suono', 3]
# ['suora', 3]
# ['superbia', 4]
# ['superbo', 4]
# ['superno', 4]
# ['supplica', 2]
# ['surgere', 2]
# ['suso', 2]
# ['sussistenza', 8]
# ['sustanzia', 5]
# ['svegliato', 7]
# ['sventura', 6]
# ['sventurato', 8]
# ['taccia', 2]
# ['tacco', 2]
# ['tacere', 4]
# ['tacito', 2]
# ['taglia', 2]
# ['tagliamento', 8]
# ['tagliata', 6]
# ['taglio', 2]
# ['tale', 2]
# ['talento', 4]
# ['talora', 4]
# ['talvolta', 5]
# ['tamburo', 5]
# ['tana', 2]
# ['tanto', 2]
# ['tantosto', 5]
# ['tardi', 2]
# ['tardo', 2]
# ['tasca', 2]
# ['tasta', 2]
# ['tatto', 2]
# ['tauro', 2]
# ['taverna', 4]
# ['te', 2]
# ['tebano', 4]
# ['teco', 2]
# ['tedesco', 4]
# ['tegghia', 2]
# ['tela', 2]
# ['tele', 2]
# ['telo', 2]
# ['tema', 2]
# ['temo', 2]
# ['tempera', 2]
# ['temperanza', 7]
# ['temperato', 7]
# ['tempesta', 5]
# ['tempia', 2]
# ['tempio', 2]
# ['templo', 2]
# ['tempo', 2]
# ['tempra', 2]
# ['tenace', 4]
# ['tencione', 6]
# ['tenebroso', 7]
# ['tenere', 4]
# ['tenero', 2]
# ['tentare', 5]
# ['tenuta', 4]
# ['tenuto', 4]
# ['tepidezza', 6]
# ['termine', 2]
# ['terra', 2]
# ['terragno', 5]
# ['terrestro', 5]
# ['terribile', 5]
# ['terribilmente', 10]
# ['terso', 2]
# ['terza', 2]
# ['terzina', 5]
# ['terzo', 2]
# ['tesa', 2]
# ['teschio', 2]
# ['tesoro', 4]
# ['test', 2]
# ['testa', 2]
# ['testamento', 7]
# ['teste', 2]
# ['testeso', 5]
# ['testimonianza', 10]
# ['testimonio', 7]
# ['testo', 2]
# ['tetragono', 5]
# ['tetro', 2]
# ['tetto', 2]
# ['tifo', 2]
# ['tigna', 2]
# ['tignoso', 5]
# ['timido', 2]
# ['tinta', 2]
# ['tintinno', 5]
# ['tinto', 2]
# ['tirannia', 7]
# ['tiranno', 4]
# ['tirato', 4]
# ['tiro', 2]
# ['tizio', 2]
# ['tocca', 2]
# ['toccata', 5]
# ['tocche', 2]
# ['tocco', 2]
# ['tolto', 2]
# ['tomba', 2]
# ['tondo', 2]
# ['topazio', 4]
# ['topo', 2]
# ['toppa', 2]
# ['toppo', 2]
# ['torello', 4]
# ['torma', 2]
# ['tormenta', 5]
# ['tormento', 5]
# ['tornare', 5]
# ['tornata', 5]
# ['torneare', 6]
# ['torno', 2]
# ['toro', 2]
# ['torre', 2]
# ['torrente', 5]
# ['torso', 2]
# ['torta', 2]
# ['torto', 2]
# ['tortura', 5]
# ['toscano', 5]
# ['tosco', 2]
# ['tosto', 2]
# ['tota', 2]
# ['traccia', 3]
# ['tracotanza', 7]
# ['tradimento', 7]
# ['traditore', 7]
# ['trafitta', 5]
# ['tragedo', 5]
# ['tragetto', 5]
# ['tragitto', 5]
# ['trama', 3]
# ['trani', 3]
# ['tranquillo', 7]
# ['transito', 3]
# ['translato', 7]
# ['trapasso', 5]
# ['trapunta', 5]
# ['trarre', 3]
# ['trascorso', 6]
# ['trasmutabile', 8]
# ['trasmutare', 8]
# ['trasparere', 6]
# ['trastulla', 6]
# ['trastullo', 6]
# ['tratta', 3]
# ['tratto', 3]
# ['travagliato', 9]
# ['traversa', 5]
# ['traverso', 5]
# ['tre', 3]
# ['trecento', 5]
# ['tremante', 5]
# ['tremare', 5]
# ['trenta', 3]
# ['trentino', 6]
# ['tresca', 3]
# ['trestizia', 6]
# ['tricordo', 5]
# ['triegua', 4]
# ['triforme', 5]
# ['trina', 3]
# ['trino', 3]
# ['tripartito', 8]
# ['tripudio', 5]
# ['triste', 3]
# ['tristizia', 6]
# ['tristo', 3]
# ['trivia', 3]
# ['troia', 3]
# ['troiano', 5]
# ['tromba', 3]
# ['trombetta', 6]
# ['tronco', 3]
# ['troncone', 6]
# ['trono', 3]
# ['troppo', 3]
# ['trottare', 6]
# ['trovare', 5]
# ['trovata', 5]
# ['trovato', 5]
# ['truono', 4]
# ['tuba', 2]
# ['tulio', 2]
# ['tumulto', 4]
# ['tuo', 2]
# ['tuono', 3]
# ['tura', 2]
# ['turba', 2]
# ['turbato', 5]
# ['turbo', 2]
# ['turno', 2]
# ['tuttavia', 7]
# ['tutto', 2]
# ['ubertà', 6]
# ['ubi', 1]
# ['ubidente', 5]
# ['uccellatoio', 9]
# ['uccello', 4]
# ['udire', 3]
# ['udita', 3]
# ['udito', 3]
# ['ulivo', 3]
# ['ultima', 1]
# ['ultimamente', 8]
# ['ultimo', 1]
# ['umano', 3]
# ['umido', 1]
# ['umiltà', 6]
# ['uncino', 4]
# ['undici', 1]
# ['unghia', 1]
# ['uniforme', 5]
# ['unito', 3]
# ['universo', 5]
# ['uno', 1]
# ['unqua', 1]
# ['unquanche', 5]
# ['unquanco', 5]
# ['unque', 1]
# ['uomo', 2]
# ['uopo', 2]
# ['urbano', 4]
# ['urlare', 4]
# ['urto', 1]
# ['usanza', 3]
# ['usare', 3]
# ['usata', 3]
# ['usato', 3]
# ['uscio', 1]
# ['uscire', 4]
# ['uscita', 4]
# ['uso', 1]
# ['usura', 3]
# ['usuriere', 6]
# ['uva', 1]
# ['vacante', 4]
# ['vacca', 2]
# ['vado', 2]
# ['vagante', 4]
# ['vaghezza', 5]
# ['vagina', 4]
# ['vaglia', 2]
# ['vaglio', 2]
# ['vago', 2]
# ['vaio', 2]
# ['valente', 4]
# ['valle', 2]
# ['vallea', 5]
# ['vallone', 5]
# ['valore', 4]
# ['vampa', 2]
# ['vangelio', 5]
# ['vangelista', 7]
# ['vanità', 6]
# ['vanni', 2]
# ['vano', 2]
# ['vantaggio', 5]
# ['vanto', 2]
# ['vapore', 4]
# ['varco', 2]
# ['varo', 2]
# ['vasello', 4]
# ['vaso', 2]
# ['vaticano', 6]
# ['ve', 2]
# ['vecchia', 2]
# ['vecchio', 2]
# ['vece', 2]
# ['vedente', 4]
# ['vedere', 4]
# ['vedova', 2]
# ['vedovella', 6]
# ['vedovo', 2]
# ['veduta', 4]
# ['veduto', 4]
# ['vegghia', 2]
# ['veggia', 2]
# ['veggio', 2]
# ['veggiolo', 6]
# ['veglio', 2]
# ['veiculo', 3]
# ['vela', 2]
# ['velame', 4]
# ['veleno', 4]
# ['velle', 2]
# ['vello', 2]
# ['velo', 2]
# ['veloce', 4]
# ['veltro', 2]
# ['vena', 2]
# ['vendemmia', 5]
# ['vendetta', 5]
# ['venduto', 5]
# ['venerabile', 6]
# ['venire', 4]
# ['ventesimo', 5]
# ['venti', 2]
# ['venticinque', 7]
# ['ventidue', 7]
# ['ventiquattro', 8]
# ['vento', 2]
# ['ventraia', 6]
# ['ventre', 2]
# ['ventura', 5]
# ['venturo', 5]
# ['venusto', 4]
# ['venuta', 4]
# ['venuto', 4]
# ['ver', 2]
# ['vera', 2]
# ['verace', 4]
# ['veramente', 6]
# ['verbo', 2]
# ['verde', 2]
# ['verdura', 5]
# ['vere', 2]
# ['verga', 2]
# ['vergine', 2]
# ['vergogna', 5]
# ['veritate', 6]
# ['verità', 6]
# ['vermena', 5]
# ['vermiglio', 5]
# ['vermo', 2]
# ['vernaccia', 5]
# ['verno', 2]
# ['vero', 2]
# ['veronese', 6]
# ['veronica', 4]
# ['verso', 2]
# ['vertute', 5]
# ['vertù', 5]
# ['vespa', 2]
# ['vespero', 2]
# ['vessillo', 5]
# ['vesta', 2]
# ['veste', 2]
# ['vestigio', 5]
# ['vestimento', 7]
# ['vestito', 5]
# ['vetro', 2]
# ['vetta', 2]
# ['vetusto', 4]
# ['via', 2]
# ['viaggio', 3]
# ['vicario', 4]
# ['vice', 2]
# ['vicenda', 4]
# ['vicino', 4]
# ['vico', 2]
# ['vie', 2]
# ['vigilia', 4]
# ['vigna', 2]
# ['vignaio', 5]
# ['vigore', 4]
# ['vile', 2]
# ['villa', 2]
# ['villanello', 7]
# ['villania', 7]
# ['villano', 5]
# ['viltade', 5]
# ['viltà', 5]
# ['vime', 2]
# ['vincastro', 5]
# ['vincere', 2]
# ['vinci', 2]
# ['vinco', 2]
# ['vino', 2]
# ['vinto', 2]
# ['violenza', 5]
# ['vipera', 2]
# ['viro', 2]
# ['virtude', 5]
# ['virtute', 5]
# ['virtù', 5]
# ['visaggio', 4]
# ['visibile', 4]
# ['visione', 5]
# ['visivo', 4]
# ['viso', 2]
# ['vispistrello', 9]
# ['vista', 2]
# ['visto', 2]
# ['vita', 2]
# ['vite', 2]
# ['vittima', 2]
# ['vittore', 5]
# ['vittoria', 5]
# ['vituperio', 6]
# ['viva', 2]
# ['vivace', 4]
# ['vivagno', 4]
# ['vivanda', 4]
# ['vivere', 2]
# ['vivo', 2]
# ['vizio', 2]
# ['vizzo', 2]
# ['vocale', 4]
# ['voce', 2]
# ['voglia', 2]
# ['voglioso', 6]
# ['voi', 2]
# ['voialtri', 4]
# ['volante', 4]
# ['volare', 4]
# ['volere', 4]
# ['volgare', 5]
# ['volgere', 2]
# ['volo', 2]
# ['volontieri', 8]
# ['volontà', 7]
# ['volpe', 2]
# ['volta', 2]
# ['volto', 2]
# ['volume', 4]
# ['voluto', 4]
# ['vosco', 2]
# ['vostro', 2]
# ['votivo', 4]
# ['voto', 2]
# ['vulcano', 5]
# ['vulgo', 2]
# ['vuoi', 3]
# ['zanca', 2]
# ['zanzara', 5]
# ['zara', 2]
# ['zavorra', 4]
# ['zefiro', 2]
# ['zelo', 2]
# ['zita', 2]
# ['zodiaco', 4]
# ['zona', 2]
# ['zucca', 2]
# ['zuffa', 2]
