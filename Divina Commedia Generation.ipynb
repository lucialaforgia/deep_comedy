# %% [markdown]
# # Divina Commedia Generation

# %%
import os
import sys
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import numpy as np
import tensorflow as tf
tf.get_logger().setLevel('ERROR')

from dante_by_tonedrev_syl.data_preparation import text_in_rev_syls, text_in_syls_rhyme
from dante_by_tonedrev_syl.text_processing import clean_comedy, prettify_text, special_tokens
from dante_by_tonedrev_syl.generate_dante import generate_text
from utils import save_vocab, load_vocab, save_syls_list, load_syls_list

working_dir = os.path.join(os.path.abspath('.'), 'dante_by_tonedrev_syl')

# %% [markdown]
# Loading the rhyme and verse vocabularies

# %%
logs_dir = os.path.join(working_dir, 'logs')
os.makedirs(logs_dir, exist_ok = True) 
vocab_file_rhyme = os.path.join(logs_dir, 'vocab_rhyme.json')
vocab_file_verse = os.path.join(logs_dir,  'vocab_verse.json')

vocab_rhyme, idx2syl_rhyme, syl2idx_rhyme = load_vocab(vocab_file_rhyme)
vocab_verse, idx2syl_verse, syl2idx_verse = load_vocab(vocab_file_verse)

vocab_size_rhyme = len(vocab_rhyme)
vocab_size_verse = len(vocab_verse)

# %% [markdown]
# Loading the rhyme and verse models already trained

# %%
models_dir = os.path.join(working_dir, 'models')
os.makedirs(models_dir, exist_ok = True) 
model_file_verse = os.path.join(models_dir, "dante_by_tonedrev_syl_verse_model.h5")
model_file_rhyme = os.path.join(models_dir, "dante_by_tonedrev_syl_rhyme_model.h5")

model_verse = tf.keras.models.load_model(model_file_verse)
model_rhyme = tf.keras.models.load_model(model_file_rhyme)

# %% [markdown]
# Models summary

# %%
model_rhyme.summary()
print('\n')
model_verse.summary()
# Out:
# Model: "RhymeNetwork"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 580, 256)          379392
# _________________________________________________________________
# last_lstm (LSTM)             (None, 580, 512)          1574912
# _________________________________________________________________
# output (Dense)               (None, 580, 1482)         760266
# =================================================================
# Total params: 2,714,570
# Trainable params: 2,714,570
# Non-trainable params: 0
# _________________________________________________________________
#
#
# Model: "VerseNetwork"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 100, 256)          1499904
# _________________________________________________________________
# last_lstm (LSTM)             (None, 100, 1024)         5246976
# _________________________________________________________________
# output (Dense)               (None, 100, 5859)         6005475
# =================================================================
# Total params: 12,752,355
# Trainable params: 12,752,355
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model_rhyme, show_shapes=True, show_layer_names=True)
# Out:
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')

# %%
tf.keras.utils.plot_model(model_verse, show_shapes=True, show_layer_names=True)
# Out:
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')

# %% [markdown]
# Loading sequence of rhyme to build the start sequence of rhyme

# %%
SEQ_LENGTH_RHYME = model_rhyme.get_layer('embedding').output.shape[1]


text_in_syls_rhyme_file = os.path.join(working_dir, 'text_in_syls_rhyme.json')

if os.path.isfile(text_in_syls_rhyme_file):
    syls_rhyme_list = load_syls_list(text_in_syls_rhyme_file)
else:
    syls_rhyme_list = text_in_syls_rhyme(divine_comedy)
    save_syls_list(syls_rhyme_list, text_in_syls_rhyme_file)

# syls_rhyme_list = text_in_syls_rhyme(divine_comedy_r)

#index_eoc = syls_rhyme_list.index(special_tokens['END_OF_CANTO']) + 1
indexes = [i for i, x in enumerate(syls_rhyme_list) if x == special_tokens['END_OF_CANTO'] and i > SEQ_LENGTH_RHYME]
index_eoc = np.random.choice(indexes) + 1
start_idx = max(0, index_eoc - SEQ_LENGTH_RHYME)
start_seq_rhyme = syls_rhyme_list[start_idx:index_eoc]

# %% [markdown]
# Loading sequence of verse to build the start sequence of verse

# %%
SEQ_LENGTH_VERSE = model_verse.get_layer('embedding').output.shape[1]


text_in_syls_verse_file = os.path.join(working_dir, 'text_in_syls_verse.json')

if os.path.isfile(text_in_syls_verse_file):
    syls_verse_list = load_syls_list(text_in_syls_verse_file)
else:
    syls_verse_list = text_in_rev_syls(divine_comedy)
    save_syls_list(syls_verse_list, text_in_syls_verse_file)

# syls_verse_list = text_in_rev_syls(divine_comedy_v)
indexes = [i for i, x in enumerate(syls_verse_list) if x == special_tokens['END_OF_VERSO'] and i > SEQ_LENGTH_VERSE]
index_eov = np.random.choice(indexes)
start_idx = max(0, index_eov - SEQ_LENGTH_VERSE)
start_seq_verse = syls_verse_list[start_idx:index_eov]

# %% [markdown]
# Generating the text

# %%
generated_text, generated_text_no_tone = generate_text(model_rhyme, model_verse, special_tokens, vocab_size_rhyme, vocab_size_verse, syl2idx_rhyme, idx2syl_rhyme, syl2idx_verse, idx2syl_verse, SEQ_LENGTH_RHYME, SEQ_LENGTH_VERSE, start_seq_rhyme, start_seq_verse, temperature=1.0)
# Out:
# CANTO
# e ròtti più e quèsta compagnìa
# tal pàrte tùtta 'l presènte dòpo
# che tu vedrài dinànzi a la sùa vìa
#
# da quèlla o quèlla nùvola d'ìsopo
# potrète su per la presènte rìssa
# ma l'àltro che per quèsto vòlto tòpo
#
# che più non si parèggia 'mo' e 'ìssa'
# ma prìa che dicèa assài ben s'accòppia
# ne l'àltra trìsta giustamènte fìssa
#
# ed èi non hài tu vòi siète e ciò ch'el scòppia
# in te magnificènza in te pòi
# che purgatòrio torstàto non ti dòppia
#
# or ti facëàn nòi più vèrso nòi
# sòno schernìti con dànno e con bèffa
# stàva a udìr turbàrsi e làscia lor nòi
#
# la pòrta sòvra 'l mal volèr s'agguèffa
# u' la natùra del mòndo fedèli
# ciascùn da l'àltra lièvre ch'èlli àcceffa'
#
# tu vèli m'hànno del cièlo àncora pèli
# ciò che l'aspètto in sé àvea contènto
# quèsti òrdini non èbber li facèli
#
# e salìr se non può 'l càlor convènto
# pòco còlpo per lo mòndo il diètro
# per lo nòvo avarìzia fòsse sènto
#
# dòve nòta da bercercàr per vètro
# turbàto un pòco d'òra e tra ' rèi
# ma tu perché da quèlla dèntro 'mpètro
#
# quàndo cominciò a li òcchi mièi
# là e nòi andavàm àrco la fàccia
# non si rìchiudon per èsser ti fèi
#
# sapèva che la vòstra còsta giàccia
# e sì còme splendèsse tànto scèndere
# e fuòr le pecorèlle a pàscer càccia
#
# dòve sembiànte tal consìglio rèndere
# caccerà da li tuòi prièghi cortèse
# pòi c'hài pietà del nòstro mal prèndere
#
# e fé piànger di sé i fòlli e i tìglia
# vèder tànto che si fé scàla col pèlo
# non cresìa cincinnàto e cornìglia
#
# che del làto ònde 'l cammìn consìglio
# ùscia di là c'ha sì benìgno aspètto
# lo dì de lo 'mperadòr di gìglio
#
# e mostròmmi ùna piàga a sòmmo 'l pètto
# ché la fàccia per l'ùna e l'àltra guància
# in sta al vènto si partì 'l dilètto
#
# pàdre e suòcero fu del mal di frància
# quàndo la còlpa sùa viziàta e lòrda
# quàl di sùbito rìso de la lància
#
# ìo chi credìti che 'n sé ricòrda
# che ge se quàndo fu dal mènto al nàso
# diss' ìo che fài tu e quèsta còrda
#
# dìmmi s'ìo vedèssi qui rimàso
# ma qui tàcer da che dìte siède
# che non cotèsti c'ha son fàtto vàso
#
# che mèmbra feminìne avièno e drìtto riède
# e pòi ch'a la cagiòne ònde alcìsa
# che sègue quèl che non mòlto mi ridiède
#
# per lo màggior don che dìo per la sùa guìsa
# sì ch'ìo non morì' qui non si puòte
# ma qui ìndi a l'ettèrna lùce rìsa
#
# nel tèmpi che colà 'vùnque si ruòte
# còme dìce di prèsso sonò fòrse
# gridàva tùtta colùi che ti percuòte
#
# ma 'nfìno a gìro tùtta in sé tòrse
# quìndi m'appàrve il tèmperar di giòve
# m'èra inginocchiàto e ridïàl trascòrse
#
# non fòga l'un de l'àltro intòrno mòve
# ad àltro splèndor di tal milìzia
# con bàsso frònda di venùti altròve
#
# per la mondìzia che la giustìzia
# per la freddùra ciascùn sentimènto
# è da sinìstra con l'àntica nequìzia
#
# chinàti a sinìstra e al tormènto
# venìmmo al pùnto fìsso di gèndo intàte
# di nèbbia e 'l cièl di sòpra fèce intènto
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-0c4bb46f0b38> in <module>
# ----> 1 generated_text, generated_text_no_tone = generate_text(model_rhyme, model_verse, special_tokens, vocab_size_rhyme, vocab_size_verse, syl2idx_rhyme, idx2syl_rhyme, syl2idx_verse, idx2syl_verse, SEQ_LENGTH_RHYME, SEQ_LENGTH_VERSE, start_seq_rhyme, start_seq_verse, temperature=1.0)
#
# ~/Desktop/UNIBO/DEEP LEARNING/deep_comedy/dante_by_tonedrev_syl/generate_dante.py in generate_text(model_rhyme, model_verse, special_tokens, vocab_size_rhyme, vocab_size_verse, syl2idx_rhyme, idx2syl_rhyme, syl2idx_verse, idx2syl_verse, seq_length_rhyme, seq_length_verse, start_seq_rhyme, start_seq_verse, temperature)
#      73
#      74
# ---> 75             prediction_verse = model_verse.predict(x_verse, verbose=0)
#      76             prediction_verse = tf.squeeze(prediction_verse, 0)[-1]
#      77             prediction_verse = prediction_verse / temperature
#
# ~/Desktop/UNIBO/DEEP LEARNING/deep_comedy/venv/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     128       raise ValueError('{} is not supported in multi-worker mode.'.format(
#     129           method.__name__))
# --> 130     return method(self, *args, **kwargs)
#     131
#     132   return tf_decorator.make_decorator(
#
# ~/Desktop/UNIBO/DEEP LEARNING/deep_comedy/venv/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1597           for step in data_handler.steps():
#    1598             callbacks.on_predict_batch_begin(step)
# -> 1599             tmp_batch_outputs = predict_function(iterator)
#    1600             if data_handler.should_sync:
#    1601               context.async_wait()
#
# ~/Desktop/UNIBO/DEEP LEARNING/deep_comedy/venv/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~/Desktop/UNIBO/DEEP LEARNING/deep_comedy/venv/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     812       # In this case we have not created variables on the first call. So we can
#     813       # run the first trace but we should fail if variables are created.
# --> 814       results = self._stateful_fn(*args, **kwds)
#     815       if self._created_variables:
#     816         raise ValueError("Creating variables on a non-first call to a function"
#
# ~/Desktop/UNIBO/DEEP LEARNING/deep_comedy/venv/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# ~/Desktop/UNIBO/DEEP LEARNING/deep_comedy/venv/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1841       `args` and `kwargs`.
#    1842     """
# -> 1843     return self._call_flat(
#    1844         [t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1845          if isinstance(t, (ops.Tensor,
#
# ~/Desktop/UNIBO/DEEP LEARNING/deep_comedy/venv/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1921         and executing_eagerly):
#    1922       # No tape is watching; skip to running the function.
# -> 1923       return self._build_call_outputs(self._inference_function.call(
#    1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#
# ~/Desktop/UNIBO/DEEP LEARNING/deep_comedy/venv/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     543       with _InterpolateFunctionError(self):
#     544         if cancellation_manager is None:
# --> 545           outputs = execute.execute(
#     546               str(self.signature.name),
#     547               num_outputs=self._num_outputs,
#
# ~/Desktop/UNIBO/DEEP LEARNING/deep_comedy/venv/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# Model Evaluation

# %%
generated_canto_file = os.path.join('.', "generated_cantos", "generated_canto_tonedrev_model.txt")

# %%
#import
import os
import sys
sys.path.append(os.path.join('.', 'other_metrics') )
import other_metrics.metrics as om
from other_metrics.ngrams_plagiarism import ngrams_plagiarism

import our_metrics.metrics as m
from dante_by_tonedrev_syl.text_processing import clean_comedy, prettify_text, special_tokens, remove_punctuation

# %%
#divine comedy
divine_comedy_file = os.path.join('.', "divina_commedia", "divina_commedia_accent_UTF-8.txt") 
with open(generated_canto_file,"r", encoding='utf-8') as f:
    generated_canto = f.read()

with open(divine_comedy_file,"r", encoding='utf-8') as f:
    divine_comedy = f.read()

divine_comedy = clean_comedy(divine_comedy, special_tokens)
divine_comedy = prettify_text(divine_comedy, special_tokens)
divine_comedy = remove_punctuation(divine_comedy)

evaluation_results = {}

# %%
def evaluate_other_metrics(generated_canto, divine_comedy):

    generated_canto_list = generated_canto.split("\n")
    generated_canto_list = [line.strip() for line in generated_canto_list if line != 'CANTO']
    generated_canto = "\n".join(generated_canto_list)

    divine_comedy_list = divine_comedy.split("\n")
    divine_comedy_list = [line.strip() for line in divine_comedy_list if line != 'CANTO']
    divine_comedy = "\n".join(divine_comedy_list)


    evaluation_results = {}
    evaluation_results = om.eval(generated_canto, verbose=False, synalepha=True, permissive=False, rhyme_threshold=1.0)

    ngrams_plagiarism_score = ngrams_plagiarism(generated_canto, divine_comedy, n=4)

    evaluation_results['Plagiarism'] =  ngrams_plagiarism_score

    return evaluation_results
def evaluate_our_metrics(generated_canto, divine_comedy):

    generated_canto_list = generated_canto.split("\n")
    generated_canto_list = [line.strip() for line in generated_canto_list if line != 'CANTO']
    generated_canto = "\n".join(generated_canto_list)

    divine_comedy_list = divine_comedy.split("\n")
    divine_comedy_list = [line.strip() for line in divine_comedy_list if line != 'CANTO']
    divine_comedy = "\n".join(divine_comedy_list)

    evaluation_results = {}

    evaluation_results = m.eval(generated_canto, synalepha=True)

    return evaluation_results

# %%
print(generated_canto)
# Out:
# CANTO
# sempre l'amor che son fravati santo'
# e forse vedi il lume di paradiso
# allora il cor secondo predicanto
#
# e l'altra non pur lo suo proprio riso
# che fece me e più e per quelbrezza
# sì che veggiate il duca mio avviso
#
# colui ch'a lei tanta allegrezza
# ma costui puose il mondo in tanta pace
# pur o gente sicura ricchezza
#
# per lo dolce che lì riguardia face
# ma nel mondo del martiro che divenne
# agulando prima e poi con più vivace
#
# e simigliante poi a dir li venne
# che dicëa alcuna cosa e marte
# sì che vo far morrà del monte penne
#
# a la poeta che 'n osa onde si parte
# con una voce detto vato coro
# veduto hai figlio e se' venuto in parte
#
# però de vero in tristi di coloro
# però a la rimasa dietro ond' io
# e che ne la speranza di costoro
#
# sì volsi li occhi a li occhi segnor mio
# sì che come fa l'uom che tanto vaca
# e dolcezza di dì l'andare a dio
#
# dallato m'era solo il mio cloaca
# ch'emisperio de l'universo
# fatto m'hai voto poi non agnel si placa
#
# e vinse in camlo seder de l'universo
# da tre e a noiga va da dimane
# poi lento chiesi e del color consperso
#
# non per li occhi ma perché membra umane
# lo primo a lui rispuose altrui la parlanza
# noi andavam per la gente profane
#
# tanto sustima di miglior sembianza
# poscia fui e fu' chiamato fue
# non mi ditemi tal quanto possanza
#
# vince sì che li fier l'opere sue
# con questi vi lenude e spaventata
# là 've 'l tacer mi fé quel che tu ti piue
#
# e questenebraron sì che ben levata
# e perché 'l poggio ripolicleto
# e per acquisto d'oro usata
#
# per acquisto d'esto viver lieto
# e sisto e pïo e calisto e urbano
# sovra colui che l'ovra tanto fleto
#
# che non corusca con cristo è romano
# uno aspettar tacendo non sedesse
# di metallo m'è dida cristiano
#
# tosto di saettaron me dicesse
# onde li pata che 'l suo farsi pusillo
# che rendea me perché non potesse
#
# per ch'al maestro parve di sigillo
# e per pugnar per accender li daci
# ritornarmi di dio vuol disfavillo
#
# poi la polver si s'arrestin rapaci
# ascoltava il tuo veder tutti i paschi
# e l'occhio de la vista lui che giaci
#
# verbo vien bene usar quel ben seguaschi
# la gran barone il cui questo concipio
# oltre non vidi e però stante caschi
#
# sì dinanzi la graürati inscipio
# non che la gente che nel nostro mondo
# ch'io domandava il mio vider principio
#
# quasi negava per lo mortal pondo
# e prima ch'io a dimandar la bocca
# incominciò se tanto diascondo
#
# e come di vapor gelati fiocca
# tanto d'indugio nostro quando 'l corno
# sì quelli a cui troppo disir non tocca
#
# la terra di veder l'etera addorno
# ma che di lì novapor trïunfanti
# e se disposizion che questo giorno
#
# e poco un vetro e non d'acqua sembianti
# con le braccia gradir la mia siri molto
# che lui e in me sì come davanti
#
# perché 'l danno d'ambrosïa assolto
# allor cangiandosi le cose adima
# e in giro per figere al volto
#
# e circuncicilian che mugghiò prima
# che tu saprai di sua corda e l'arco
# perché sì dolcemente per che declima
#
# formar la nuvola di fecer varco
# e talvolta l'uno alto e l'altro lito
# oma fia a ciò di lei farà carco
#
# la luna quasi a l'alto soro sito
# sì di fulgore e da sua risplendea
# ancor se' tu ch'onora partito
#
# sì tosto come il vento a noi paesi
# non fa la lupa che tutte le move
# ancora la rubata solomea
#
# ond' elli a me avaccio sarai dove
# in alcun vero suo per accertarsi
# che monte avenranno rei che i move
#
# natura nel percuoter d'i ciocchi arsi
# diss' el movendo li occhi le faville
# ti didee se tu perché fosse gurarsi
#
# e te ricominciò far più di mille
# e non per la pioggia non parea poco
# raggiunse con l'occhio m'era dipartille
#
# discendendo l'arco per lo suo loco
# la bufera infernal che mai non vidi
# ad uno ad uno e io temëa 'l foco
#
# e viltali per l'aere che mi guidi
# e tu sarai come tu ti rammenta
# che fa natura sì com' io nidi
#
# mirava fissa immobile e attenta
# e disser ma d'ingigliarsi a l'emme
# da l'onde del ciel lo mondo imprenta
#
# forza fa stella quali e quante gemme
# qui vien goccia a la sua vita giustizia
# tanza dentro dal monte a te gemme
#
# escusar puommi di quel che qui s'inizia
# come virtute come tu rimiri
# dì vider di colui che l'altra vizia
#
# non incominciò tutta non m'adiri
# tale balbuzïendo ancor contemplo
# compagni fec' io e che là il tiri
#
# tutti son questi li occhi a quell' aere templo
# la donna mia incominciò inver' la terra
# tra itato lieri come l'essemplo
#
# ciò che fosse la campa l'alta guerra
# esperïenza lieta grazia fosse quivi
# ma 'l benedetto a cui nulla si serra
#
# fanno libero da che non lo scrivo
# e sotto così lunga disïante
# questo sicuro e gaudïoso vivo
#
# la creatura ch'ebbe il bel sembiante
# e parturir si sia il mio ingegno
# li occhi lor innanzi poco t'è davante
#
# che venne in terra né dritto segno
# né l'impetrare ispirazion mi parver queta
# ne la materia non mirando regno
#
# mi qual è penelopè far lieta
# fïate intorno di senianza si mise
# e io a lui che di se ne fé 'l pianeta
#
# ad altro fame sì che più si rise
# con due calcai fin che ventura
# forse dunque perché dal ciel mi guise
#
# e se non ti può però che pura
# nulla ti farà nel chiarir di fori
# li colombi adunati a la pastura
#
# giù per li splendor di mille odori
# o figliuol mio parlar ciascun s'udia
# si porivolsi a la terza non mori
#
# ma sì come ciascuno a noi venia
# un'aguglia del tuo figlia di letizia
# al piè al piè de la sua divina uscia
#
# o anima che siena ringrazia
# poi che d'entrar ne l'alto in terra nostra
# o tu ch'io vidi poi qui non si sazia
#
# nel nome di salire al mondo mostra
# e se prensiva da esser verace
# anzi 'l candor de la sembianza vostra'
#
# e di più somigliante è più vivace
# che tosto là dove governa il mondo
# di vederlo attuffare in questa pace
#
# insieme le due spirito al secondo
# se tu sa' ir ch'i' ho le cose noto
# pur a sinistra giù calando al fondo
#
# non move occhio per mille esser remoto
# che qui per acquistar questa regina
# questa fu la mia vista sì devoto
#
# vinceva l'ora mattutina
# bassando 'l viso lì come da l'orizzonte
# io dico di me di lideclina
#
# perché de li occhi di salire al monte
# quel rirando credo ch'a lo stremo
# guarda sottilmente per che la fronte
#
# e suol di state talor essere scemo
# quando piangea credo che ristora
# e là il novo giorno attenderemo
#
# l'altro gridar qui non mi dì ancora
# che l'uom de l'acqua a lui verai
# e per l'udito di ciascun dimora
#
# dimmi il ver di te son lenti passi mai
# così di venir sù subito amore
# e quando l'ali fuoro aperte assai
#
# tanto che saranno com' è parore
# già era l'angel dietro a l'obietto
# nel veder di colui che di vigore
#
# e natura a contingenze essere in diretto
# in che quanto fé licito in sua pressura
# del suo viso se' d'ogne cò letto
#
# quasi torna'mi in dietro di sé cura
# non è qui perché fanno prima bene
# e nel suo amor là giù pose a drittura
#
# e grado maggior che non la convene
# cantava rivolto ad esser virtute
# ratto ch'uscì del pieno del ciel ne pene
#
# quando noi fummo sor l'ultima salute
# però son io lì così com' io viso
# o pigna lume a punto e con virtute
#
# ma non a ricolte de sé viso
# qual puoi fallire a glorïoso primo
# a lui portar nel vedere interciso
#
# ma per andar giù nel mio rivestimo
# d'un modo prima tra 'l grifone ed esso
# amor nasce in tre modi in vostro limo
#
# che tosto dentro il suo vicin soppresso
# ché la tua città che qui si brama
# del cino a' monti scende da ciel messo
#
# come per nata de la tua fama
# e quando n'appar qua entra sormonti
# tanto mi disse il sol che 'l trario ama
#
# el disse a me noi cupide là onti
# parsi la voglia sua de l'oro ghiotto
# ché la mente mi piacëa allor impronti
#
# ché pur a dir per me però né sotto
# o siglio fei sì col spirito ch'attende
# a la divina bontà ch'è rotto
#
# col punton de la chiesa quando prende
# e quella manda a sì mal ne disira
# quella che 'l cinge solamente intende
#
# sì ch'ogne fiamma sia stanza martira
# da l'altra piccioletta luce cornice
# la volontà mutano i tornò tira
#
# io pensando per lo l'uom felice
# lutarmi nel figlio ch'ad essa è buona
# e vene lei seder la radice
#
# e io maestro molto perdona
# ed el mi scende credette son acerchi
# qual è quella parte onde ti ragiona
#
# e una melodia sì resurga
# qual si quella di colui ch'i' sono
# vela ora revena qual ti surga
#
# in te non trasse infino a la corona
# si fu nomato se' di fan d'italia
# o tu che non da corde si ragiona
#
# pria che s'io veggio la nimica
#  vergine di sua virtù trascorra
# guardate dal voler affatica
#
# quella sen va che 'ntorno si morra
# quivi levò a sempre sì compasi
# ma perché veggi mei ciò ch'io diversi
#
# ed ecco fia moderna t'accoglia
# forse a corre al pastro sol consiglia
# fu e in te altrove quei che soglia
#
# quèst' è 'l principio là onde si piglia
# rispuose 'l mio maestro voi secondo
# sì ch'io vidi com' era maraviglia
#
# io vidi per le coste e per lo fondo
# tacite a l'ombra che furon di cantate
# qua vedesti ch'ella fossa tutto 'l mondo
#
# per veder meglio ai passi pur le tate
# biscazza e tienti e perché più s'accende
# sappi ch'i' fu' di là dov' io state
#
# giù nel primo capo ch'elli avea divento
# allor di maschio femmina dimora
# lo mio ma or qui è tuo talento
#
# domi le branche l'aere a sé misura
# e al mondo di spiriti ben vani
# s'aperse 'l qual sicelrabilmente oscura
#
# quale de l'arzanà de' viniziani
# tutti girando a la tenace pece
# ascoltando mio parve mi divenni
#
# ricominciò la mente che di te vece
# e contra piccioletta schiera mano
# intrammo a ricominciò vïaggi fece
#
# da l'altra dita pesce per mano
# aprimi li occhi e io non gliel' apersi
# e savi si mostrava tanto lano
#
# tutti dicean pria se ben diversi
# se la sentenza d'ogne magagna
# come 'l ramarro sotto poi dispersi
#
# e però se' di quella turba magna
# e come fregiati e per sua opra
# che piegasse il carro se si ribagna
#
# ed ella non par vivo ancor di sopra

# %%
## Evaluation other metrics on generated canto ### 
print('\nEVALUATING OTHER METRICS ON GENERATED CANTO...')
evaluation_results = evaluate_other_metrics(generated_canto, divine_comedy)

print('\nOTHER METRICS ON GENERATED CANTO:')
for k, v in evaluation_results.items():
    print('{}: {}'.format(k, v)) 

##################################################

### Evaluation our metrics on generated canto ####
print('\nEVALUATING OUR METRICS ON GENERATED CANTO...')
evaluation_results = evaluate_our_metrics(generated_canto, divine_comedy)

print('\nOUR METRICS ON GENERATED CANTO:')
for k, v in evaluation_results.items():
    print('{}: {}'.format(k, v))

##################################################
# Out:
# EVALUATING OTHER METRICS ON GENERATED CANTO...
#
# OTHER METRICS ON GENERATED CANTO:
# Number of putative terzine: 89
# Number of well formed terzine: 89
# Average structuredness: 0.9972144846796658
# Average hendecasyllabicness: 0.9311797752808986
# Average rhymeness: 0.9469696969696971
# Plagiarism: 0.858359957401491
#
# EVALUATING OUR METRICS ON GENERATED CANTO...
#
# OUR METRICS ON GENERATED CANTO:
# Number of verses: 268
# Number of strophes: 90
# Number of well formed terzine: 89
# Last single verse: True
# Average syllables per verse: 11.10 ± 0.63
# Hendecasyllables by tone: 0.7164
# Number of rhymes: 0
